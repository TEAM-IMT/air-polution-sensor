# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/Data_csv/PuneData_UseThis/'
# !ls
# Out:
# /content/drive/MyDrive/IMT Atlantique/Project_S5_Air/Data_csv/PuneData_UseThis
# August2019  June2019  November2018toMay2019  Pune_SensorLocationDistances.csv
# July2019    May2019   October2019	     September2019

# %%
import dateutil.parser
from dateutil.parser import parse 
import pandas as pd  # This is always assumed but is included here as an introduction.
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series
import pandas as pd
import os

from pandas.plotting import autocorrelation_plot
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

import matplotlib as mpl

mpl.rcParams['agg.path.chunksize'] = 10000

# %% [markdown]
# # Data Analysis Dictionary Directories

# %%
import numpy as np
import pandas as pd
import os

# %%
path = '/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/Data/PuneData_UseThis/'
pathdir  = np.array(os.listdir(path))
csv_file_list = {}
aux = []


for dirname in pathdir:
  if os.path.isdir(path + dirname):
    pathcsv = path + dirname + '/' + 'csv' + '/'
    dir_files = []
    dir_files = np.array(os.listdir(pathcsv))
    #display(dir_files)
    list_names_files = []
    for dirnamecsv in dir_files:
      #display(dirnamecsv)
      list_names_files.append(pd.read_csv(pathcsv + dirnamecsv))
      
    merged_df = []
    merged_df = pd.concat(list_names_files)
    #display(merged_df)
    csv_file_list[dirname] = merged_df
    
#super_df = pd.concat(aux)
display(csv_file_list)
# Out:
# {'August2019':        SOUND TEMPRATURE_MIN  ... UV_MAX PM2_MAX
#  0     81.186             23  ...      3       1
#  1     81.186             23  ...      3       1
#  2     81.186             23  ...      3       1
#  3     81.186             23  ...      3       1
#  4      82.85             23  ...      3       1
#  ...      ...            ...  ...    ...     ...
#  2413     NaN            NaN  ...      0       0
#  2414     NaN            NaN  ...      0       0
#  2415     NaN             22  ...    NaN       0
#  2416     NaN             22  ...    NaN       0
#  2417     NaN            NaN  ...    NaN     NaN
#
#  [106252 rows x 31 columns],
#  'July2019':         SOUND  TEMPRATURE_MIN  ... UV_MAX PM2_MAX
#  0     102.009             NaN  ...    1.5    16.0
#  1     102.009             NaN  ...    1.5    15.0
#  2         NaN             NaN  ...    NaN     NaN
#  3         NaN             NaN  ...    NaN     NaN
#  4         NaN             NaN  ...    NaN     NaN
# ...

# %%
super_df = pd.concat(csv_file_list.values(), keys=csv_file_list.keys())
super_df.reset_index(level=0 , inplace=True)
super_df.rename(columns={'level_0': 'Date'}, inplace=True)
super_df
# Out:
#                        Date  ... STATUS
# 0     November2018toMay2019  ...    NaN
# 1     November2018toMay2019  ...    NaN
# 2     November2018toMay2019  ...    NaN
# 3     November2018toMay2019  ...    NaN
# 4     November2018toMay2019  ...    NaN
# ...                     ...  ...    ...
# 2306          September2019  ...     ON
# 2307          September2019  ...     ON
# 2308          September2019  ...     ON
# 2309          September2019  ...     ON
# 2310          September2019  ...     ON
#
# [1059794 rows x 43 columns]

# %%
super_df.to_csv('/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/super_df.csv')

# %%
#super_df = super_df[['AQI', 'SO2_MAX', 'SO2_MIN', 'OZONE_MAX', 'OZONE_MIN', 'PM10_MAX','NO_MAX','NO_MIN', 'PM10_MIN', 'PM2_MAX', 'PM2_MIN','NO2_MAX', 'NO2_MIN', 'CO2_MIN', 'CO2_MAX', 'TEMPRATURE_MIN', 'TEMPRATURE_MAX', 'AIR_PRESSURE', 'SOUND', 'CO_MIN', 'CO_MAX', 'UV_MAX', 'UV_MIN', 'HUMIDITY', 'LIGHT']].astype('float')

# %%
super_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1059794 entries, 0 to 2310
# Data columns (total 43 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Date                1059794 non-null  object
#  1   DeviceId            50 non-null       object
#  2   location_name       50 non-null       object
#  3   Latitude            50 non-null       float64
#  4   Longitude           50 non-null       float64
#  5   Category            41 non-null       object
#  6   AQI                 1059786 non-null  float64
#  7   SO2_MAX             995828 non-null   object
#  8   SO2_MIN             995828 non-null   object
#  9   OZONE_MAX           995752 non-null   object
#  10  OZONE_MIN           995752 non-null   object
#  11  NO_MAX              1041686 non-null  object
#  12  NO_MIN              1041686 non-null  object
#  13  PM10_MAX            995041 non-null   object
# ...

# %%
df = csv_file_list 
df.keys()
df['November2018toMay2019'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 618656 entries, 0 to 12340
# Data columns (total 42 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   DeviceId            50 non-null      object
#  1   location_name       50 non-null      object
#  2   Latitude            50 non-null      float64
#  3   Longitude           50 non-null      float64
#  4   Category            41 non-null      object
#  5   AQI                 618648 non-null  float64
#  6   SO2_MAX             591760 non-null  object
#  7   SO2_MIN             591760 non-null  object
#  8   OZONE_MAX           587391 non-null  object
#  9   OZONE_MIN           587391 non-null  object
#  10  NO_MAX              600548 non-null  object
#  11  NO_MIN              600548 non-null  object
#  12  PM10_MAX            590704 non-null  object
#  13  PM10_MIN            590704 non-null  object
#  14  PM2_MAX             592523 non-null  object
# ...

# %%
df['November2018toMay2019'].replace('None', np.nan, inplace=True)

# %%
df['November2018toMay2019']['SO2_MAX'] = df['November2018toMay2019']['SO2_MAX'].astype(float)

# %%
df['November2018toMay2019']['Ones'] = 1
df['November2018toMay2019'].sample(5)
# Out:
#      DeviceId location_name  Latitude  ...                       NAME STATUS  Ones
# 8038      NaN           NaN       NaN  ...     Bajaj Statue Square_50     ON     1
# 3082      NaN           NaN       NaN  ...    Vadgaon_Sheri_Square_52     ON     1
# 1648      NaN           NaN       NaN  ...    Goodluck Square_Cafe_23     ON     1
# 8375      NaN           NaN       NaN  ...  ABC Farm House Junction_4     ON     1
# 296       NaN           NaN       NaN  ...       Lullanagar_Square_14  ON_ON     1
#
# [5 rows x 43 columns]

# %%
df['November2018toMay2019'].shape
# Out:
# (618656, 43)

# %%
df['November2018toMay2019']['LASTUPDATEDATETIME'] = pd.to_datetime(df['November2018toMay2019']['LASTUPDATEDATETIME'])
df['November2018toMay2019']['Year'] = df['November2018toMay2019']['LASTUPDATEDATETIME'].dt.year
df['November2018toMay2019']['Month'] = df['November2018toMay2019']['LASTUPDATEDATETIME'].dt.month
#df['November2018toMay2019'][['Year', 'Month']]

df['November2018toMay2019']['Hour'] =  df['November2018toMay2019']['LASTUPDATEDATETIME'].dt.hour
df['November2018toMay2019'][['Year', 'Month', 'Hour']]
# Out:
#          Year  Month  Hour
# 0         NaN    NaN   NaN
# 1         NaN    NaN   NaN
# 2         NaN    NaN   NaN
# 3         NaN    NaN   NaN
# 4         NaN    NaN   NaN
# ...       ...    ...   ...
# 12336  2018.0   11.0   6.0
# 12337  2018.0   11.0   6.0
# 12338  2018.0   11.0   6.0
# 12339  2018.0   11.0   5.0
# 12340  2018.0   11.0   5.0
#
# [618656 rows x 3 columns]

# %%
df['November2018toMay2019'].keys()
# Out:
# Index(['DeviceId', 'location_name', 'Latitude', 'Longitude', 'Category', 'AQI',
#        'SO2_MAX', 'SO2_MIN', 'OZONE_MAX', 'OZONE_MIN', 'NO_MAX', 'NO_MIN',
#        'PM10_MAX', 'PM10_MIN', 'PM2_MAX', 'PM2_MIN', 'NO2_MAX', 'NO2_MIN',
#        'Light', 'Humidity', 'AQI_Pollutant', 'Status', 'ON_OFF_STATUS',
#        'CO2_MIN', 'CO2_MAX', 'TEMPRATURE_MIN', 'TEMPRATURE_MAX',
#        'AIR_PRESSURE', 'SOUND', 'CO_MIN', 'CO_MAX', 'timezoneoffset', 'UV_MAX',
#        'UV_MIN', 'AQI_POLLUTANT', 'CATEGORY', 'DEVICEID', 'HUMIDITY',
#        'LASTUPDATEDATETIME', 'LIGHT', 'NAME', 'STATUS', 'Ones', 'Year',
#        'Month', 'Hour'],
#       dtype='object')

# %%
import plotly.express as px

def Box_plot(data,x_line,y_line,orient):
        #Box plot
        fig = px.box(data,x=x_line, y=y_line,orientation=orient)
        fig.show()

# %%
df['November2018toMay2019']['AQI'] = df['November2018toMay2019']['AQI'].fillna(df['November2018toMay2019']['AQI'].median())
super_df['AQI'] = super_df['AQI'].fillna(super_df['AQI'].median())

# %%
#df['November2018toMay2019'].drop(['Light','Humidity'], axis=1, inplace=True)
df['November2018toMay2019'].sample(5)
# Out:
#      DeviceId location_name  Latitude  Longitude  ... Ones    Year  Month  Hour
# 5070      NaN           NaN       NaN        NaN  ...    1  2019.0    2.0  15.0
# 2009      NaN           NaN       NaN        NaN  ...    1  2018.0   11.0   8.0
# 839       NaN           NaN       NaN        NaN  ...    1  2019.0    4.0   4.0
# 4454      NaN           NaN       NaN        NaN  ...    1  2019.0    2.0  15.0
# 9766      NaN           NaN       NaN        NaN  ...    1  2018.0   12.0   5.0
#
# [5 rows x 46 columns]

# %%
super_df.sample(2)
# Out:
#                         Date DeviceId  ...                        NAME  STATUS
# 11340  November2018toMay2019      NaN  ...  Noble Hospital junction_35      ON
# 560    November2018toMay2019      NaN  ...     Sadhu_Wasvani_Square_24   ON_ON
#
# [2 rows x 43 columns]

# %%
# df_location_SO2max = super_df.groupby(['Date',
#                                      pd.Grouper(key='LASTUPDATEDATETIME' , freq='1M')                                 
# ]).agg({'AQI': [np.mean, np.median]})
# df_location_SO2max
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-05d11bd497be> in <module>()
#       1 df_location_SO2max = super_df.groupby(['Date',
# ----> 2                                      pd.Grouper(key='LASTUPDATEDATETIME' , freq='1M')
#       3 ]).agg({'AQI': [np.mean, np.median]})
#       4 df_location_SO2max
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
# ...

# %%
df_location_SO2max.xs('August2019')['AQI'].plot()

# %%
df_avg_SO2MAX =df_location_SO2max['SO2_MAX'][['median']].reset_index()
df_avg_SO2MAX.rename(columns={'LASTUPDATEDATETIME': 'DATE', 'median': 'SO2_Avg'}, inplace=True)

# %%
df_avg_SO2MAX['month'] = df_avg_SO2MAX['DATE'].dt.month
df_avg_SO2MAX

# %%
df_avg_SO2MAX_pivot = df_avg_SO2MAX.pivot_table(values='SO2_Avg', columns= 'month', index='NAME') 
df_avg_SO2MAX_pivot

# %%
df_avg_SO2MAX_pivot.boxplot()

# %%
Box_plot(df_avg_SO2MAX,'month', 'SO2_Avg','v' )

# %% [markdown]
# # Analysis Super Dataframe

# %%
super_df = pd.read_csv('/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/super_df.csv', header=0, index_col=0)
super_df.replace({ -np.inf : np.nan, np.inf: np.nan, 'None': np.nan}, inplace=True)
super_df.drop(columns=['Light', 'Humidity', 'AQI_Pollutant', 'Status', 'ON_OFF_STATUS', 'timezoneoffset'], inplace=True)
super_df[['AQI', 'SO2_MAX', 'SO2_MIN', 'OZONE_MAX', 'OZONE_MIN', 'PM10_MAX','NO_MAX','NO_MIN', 'PM10_MIN', 'PM2_MAX', 'PM2_MIN',
          'NO2_MAX', 'NO2_MIN', 'CO2_MIN', 'CO2_MAX', 'TEMPRATURE_MIN', 'TEMPRATURE_MAX', 'AIR_PRESSURE', 'SOUND', 'CO_MIN', 'CO_MAX',
          'UV_MAX', 'UV_MIN', 'HUMIDITY']] =super_df[['AQI', 'SO2_MAX', 'SO2_MIN', 'OZONE_MAX', 'OZONE_MIN', 'PM10_MAX','NO_MAX','NO_MIN', 'PM10_MIN', 'PM2_MAX', 'PM2_MIN','NO2_MAX', 'NO2_MIN', 'CO2_MIN', 'CO2_MAX', 'TEMPRATURE_MIN', 'TEMPRATURE_MAX', 'AIR_PRESSURE', 'SOUND', 'CO_MIN', 'CO_MAX', 'UV_MAX', 'UV_MIN', 'HUMIDITY']].astype('float')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2,3,6,8,9,10,11,14,15,16,17,18,19,22,23,25,26,27,28,29,30,31,32,34,35,39,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
#### Super Dataframe

super_df['LASTUPDATEDATETIME'] = pd.to_datetime(super_df['LASTUPDATEDATETIME'])
super_df['Year'] = super_df['LASTUPDATEDATETIME'].dt.year
super_df['Month'] = super_df['LASTUPDATEDATETIME'].dt.month
super_df['Day'] = super_df['LASTUPDATEDATETIME'].dt.day


super_df['Hour'] =  super_df['Year'] = super_df['LASTUPDATEDATETIME'].dt.hour
#super_df[['Year', 'Month', 'Hour']]

# %%
super_df.loc[super_df['PM2_MAX'] > 300 , 'PM2_MAX'] = 300

# %% [markdown]
# Preprocessing Data

# %% [markdown]
# Here we normalize the data, and we make sure that the negative values of the sensors are well normalized as it is possible for the sensors to give negative values.

# %%
#####Standardize the data#####
#instanciation
from sklearn.preprocessing import StandardScaler

# stds = preprocessing.StandardScaler()

# #transformation
# Ztrain = stds.fit_transform(Xtrain) #PCA
# Ztest = stds.fit_transform(Xtest) #PCA
# Wtrain = stds.fit_transform(Ytrain) #PCA
# Wtest = stds.fit_transform(Ytest) #PCA
#ColumnsOneHot=['categorie_new_Core', 'categorie_new_Niche', 'categorie_new_Partisan',
      #  'categ_inst_Alternatif', 'categ_inst_Presse magazine',
      #  'categ_inst_Presse nationale', 'categ_inst_Presse_regionale',
      #  'categ_inst_Pure Players', 'categ_inst_TV','cluster_indexes']

#ratio_columns=[x for x in youtube_df.columns if x not in ColumnsOneHot]
ratio_columns = ['AQI', 'SO2_MAX', 'SO2_MIN', 'OZONE_MAX', 'OZONE_MIN', 'PM2_MAX', 'PM2_MIN',
       'NO2_MAX', 'NO2_MIN', 'CO2_MIN', 'CO2_MAX']
std_scale = StandardScaler().fit(super_df[ratio_columns])
super_df[ratio_columns] = std_scale.transform(super_df[ratio_columns])
copy_df = super_df[ratio_columns].copy(deep = True)

# %% [markdown]
# The principipal gases to be considered when measuring air quality are levels of ozone (O3), nitrogen dioxide (NO2), carbon dioxide (CO2), sulfur dioxide (SO2). A very important metric is the Air Quality Index (AQI) since the WHO considers it the best metric to measure air quality. PM10 is also important to consider as it refers to small solid or liquid particles of dust, ash, soot, metal particles, cement or pollen, dispersed in the atmosphere.
#
# Suspended particles of less than 2.5 microns (PM2.5) appear to be a better indicator of urban pollution than the previously used PM10. This is because PM2.5 largely comes from emissions from diesel vehicles in the city. On the other hand, the effects they have on our health are very serious, due to their great capacity to penetrate the respiratory tract. There are articles reflecting the results of research in the city of Madrid that clearly correlates the increase in PM2.5 concentration with increased hospital admissions.

# %%
cat_df = super_df.select_dtypes(include = 'object')

# %%
import missingno as msno
import matplotlib.pyplot as plt

#msno.bar(cat_df, figsize=(12, 6), fontsize=12, color='steelblue')

# %%
cat_df.drop(columns=['DeviceId', 'location_name', 'Category'], inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#msno.heatmap(cat_df, figsize=(20,20))

# %%
#copy_df.replace({ -np.inf : np.nan, np.inf: np.nan, 'None': np.nan}, inplace=True)

copy_df = copy_df[['AQI', 'SO2_MAX', 'SO2_MIN', 'OZONE_MAX', 'OZONE_MIN',  'PM2_MAX', 'PM2_MIN','NO2_MAX', 'NO2_MIN', 'CO2_MIN', 'CO2_MAX']].astype('float')

# %%
copy_df.shape
# Out:
# (1059794, 11)

# %%
import missingno as msno
import matplotlib.pyplot as plt

msno.bar(copy_df, figsize=(12, 6), fontsize=12, color='steelblue')

# %%
msno.matrix(copy_df)

# %%
msno.heatmap(copy_df)

# %% [markdown]
# This plot represents the correlation between the null values by column.
#
# If column A has a value, B also has a value, means a strong positive correlation, or a blue 1 in the chart.
#
# If A has a value, B has a null, means a strong negative correlation, or a red -1 in the chart.
#
# Here we can see how the fields relate in matters of nulls that I want to go through.

# %% [markdown]
# # Graphs per gas

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.boxplot(data= super_df, x="Hour", y="SO2_MAX", ax=axes[0], showfliers = False)
sns.boxplot(data= super_df, x="Hour", y="SO2_MIN", ax=axes[1], showfliers = False)

# %%
import seaborn as sns

fig, axes = plt.subplots(1 ,figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.lineplot(data= super_df, x="SO2_MIN", y="SO2_MAX", ax=axes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-a2945e3bd054> in <module>()
#       4 # the size of A4 paper
#       5 #fig.set_size_inches(13, 7)
# ----> 6 sns.lineplot(data= super_df, x="SO2_MIN", y="SO2_MAX", ax=axes)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.6/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     694     p._attach(ax)
#     695
# --> 696     p.plot(ax, kwargs)
# ...

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.boxplot(data= super_df, x="Hour", y="OZONE_MAX", ax=axes[0], showfliers = False)
sns.boxplot(data= super_df, x="Hour", y="OZONE_MIN", ax=axes[1], showfliers = False)

# %%
import seaborn as sns

fig, axes = plt.subplots(1 ,figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.lineplot(data= super_df, x="OZONE_MIN", y="OZONE_MAX", ax=axes)

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.boxplot(data= super_df, x="Hour", y="PM2_MAX", ax=axes[0], showfliers = False)
sns.boxplot(data= super_df, x="Hour", y="PM2_MIN", ax=axes[1], showfliers = False)

# %%
import seaborn as sns

fig, axes = plt.subplots(1 ,figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.lineplot(data= super_df, x="PM2_MIN", y="PM2_MAX", ax=axes)

# %%
import seaborn as sns

fig, axes = plt.subplots(1 ,figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.lineplot(data= super_df, x="Month", y="PM2_MAX", ax=axes)

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.boxplot(data= super_df, x="Hour", y="NO2_MAX", ax=axes[0], showfliers = False)
sns.boxplot(data= super_df, x="Hour", y="NO2_MIN", ax=axes[1], showfliers = False)

# %%
import seaborn as sns

fig, axes = plt.subplots(1 ,figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.lineplot(data= super_df, x="NO2_MIN", y="NO2_MAX", ax=axes)

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.boxplot(data= super_df, x="Hour", y="CO2_MAX", ax=axes[0], showfliers = False)
sns.boxplot(data= super_df, x="Hour", y="CO2_MIN", ax=axes[1], showfliers = False)

# %%
import seaborn as sns

fig, axes = plt.subplots(1 ,figsize=(22, 5), sharey=False)
# the size of A4 paper
#fig.set_size_inches(13, 7)
sns.lineplot(data= super_df, x="CO2_MIN", y="CO2_MAX", ax=axes)

# %%
import plotly.express as px

def Box_plot(data,x_line,y_line,orient):
        #Box plot
        fig = px.box(data,x=x_line, y=y_line,orientation=orient)
        fig.show()

# %%
#Box_plot(super_df,'Hour', 'OZONE_MIN','v' )

# %% [markdown]
# # Categorization of Data

# %% [markdown]
# There are three categories of missing data: Missing Completely at Random (MCAR), Missing at Random (MAR), Missing Not at Random (MNAR).
#
# MCAR — The missing value is missing completely at random. The propensity for a data point to be missing does not have anything to do with its hypothetical value and with the values of other variables.
#
# MAR — The missing value is missing due to some of the observed data. The propensity for a data point to be missing is not related to missing data, but it is related to some of the observed data.
#
# MNAR — The missing value is missing not at random. There are reasons for this. Often, the reasons are that the missing value depends on the hypothetical value or it is dependent on another variable’s value.

# %%
#Cramers coeff function

def cramers_stat(confusion_matrix):


  chi2 = chis2_contingency(confusion_matrix)[0]
  n= confusion_matrix.sum().sum()
  phi2 = chi2 /n
  r,k = confusion_matrix.shape
  phi2corr = max(0, phi2 - ((k-1)*(r-1)/ (n-1)))
  rcorr = r - ((r-1)**2) / (n-1)
  kcorr = k - ((k-1)**2) / (n-1)

  return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# %% [markdown]
# Multiple imputation is a process where the missing values are filled multiple times to create “complete” datasets. Multiple imputation has a lot of advantages over traditional single imputation methods. Multiple Imputation by Chained Equations (MICE) is an imputation method that works with the assumption that the missing data are Missing at Random (MAR). Recall that for MAR, the nature of the missing data is related to the observed data but not the missing data. The MICE algorithm works by running multiple regression models and each missing value is modeled conditionally depending on the observed (non-missing) values.

# %%
from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer
imputer = IterativeImputer(random_state=0)

copy2 = copy_df.copy(deep= True)

# %%
copy_df.isnull().sum().sort_values(ascending=False)/len(super_df)*100
# Out:
# CO2_MAX      9.919569
# CO2_MIN      9.919569
# NO2_MIN      7.270564
# NO2_MAX      7.270564
# PM2_MIN      6.843500
# PM2_MAX      6.843500
# OZONE_MIN    6.589111
# OZONE_MAX    6.589111
# SO2_MIN      6.576278
# SO2_MAX      6.576278
# AQI          0.000755
# dtype: float64

# %%
imputer.fit(copy2)
df =imputer.transform(copy2)

# %%
df = pd.DataFrame(df)

# %%
pd.DataFrame(df).isnull().sum().sort_values(ascending=False)/len(super_df)*100
# Out:
# 10    0.0
# 9     0.0
# 8     0.0
# 7     0.0
# 6     0.0
# 5     0.0
# 4     0.0
# 3     0.0
# 2     0.0
# 1     0.0
# 0     0.0
# dtype: float64

# %% [markdown]
# # Time Series

# %%
super_df.shape
# Out:
# (1059794, 41)

# %%
sdf2 = super_df.groupby(pd.Grouper(key='LASTUPDATEDATETIME', freq ='1H'))[['PM2_MAX', 'PM2_MIN']].agg('mean').reset_index()
#sdf2['Mean PM2'] = sdf2.groupby(['PM2_MAX','PM2_MIN']).agg('mean')

# %%
dft =  
dftr = dft[['LASTUPDATEDATETIME','PM2_MAX', 'PM2_MIN']]


dftdiff = dftr.diff()
dftdiff = dftdiff.assign(d=sdf2[['LASTUPDATEDATETIME']])
#ajout d'un colonne donnant la date
# permet de connaitre l'heure où la différence es égale à 0 où à 1h30

# %%
dftr.sort_values(by='LASTUPDATEDATETIME')
#'d' : indique la date-heure
#'Date - Heure ' : donne la diff. entre 2 instants consécutifs
# Out:
#             LASTUPDATEDATETIME   PM2_MAX   PM2_MIN
# 0    2018-11-01 05:00:00+05:30  0.020956 -0.648813
# 1    2018-11-01 06:00:00+05:30 -0.035558 -0.654904
# 2    2018-11-01 07:00:00+05:30 -0.006624 -0.654321
# 3    2018-11-01 08:00:00+05:30 -0.023948 -0.657246
# 4    2018-11-01 09:00:00+05:30  0.082768 -0.655297
# ...                        ...       ...       ...
# 8660 2019-10-28 01:00:00+05:30  0.265285  0.101039
# 8661 2019-10-28 02:00:00+05:30  0.263912  0.169967
# 8662 2019-10-28 03:00:00+05:30  0.251105  0.197763
# 8663 2019-10-28 04:00:00+05:30  0.259464  0.258050
# 8664 2019-10-28 05:00:00+05:30  0.324512  0.359392
#
# [8665 rows x 3 columns]

# %% [markdown]
# # Data Visualization

# %%
# Affichage
def plot_df(df, x, y, title="qu'est-ce ?", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
    

plot_df(dft, x=dft[['LASTUPDATEDATETIME']], y=dft[['PM2_MAX']],title='PM2MAX par heure  - RTE 01/11/2018 - 28/10/2019')
plot_df(dft, x=dft[['LASTUPDATEDATETIME']], y=dft[['PM2_MIN']],title='PM2MIN par heure  - RTE 01/11/2018 - 28/10/2019')

# %%
df_dates = super_df.set_index('LASTUPDATEDATETIME')
df_dates = super_df.groupby(pd.Grouper(key='LASTUPDATEDATETIME', freq ='1H'))[['PM2_MAX', 'PM2_MIN']].agg('mean').reset_index()
df_dates
# Out:
#             LASTUPDATEDATETIME   PM2_MAX   PM2_MIN
# 0    2018-11-01 05:00:00+05:30  0.020956 -0.648813
# 1    2018-11-01 06:00:00+05:30 -0.035558 -0.654904
# 2    2018-11-01 07:00:00+05:30 -0.006624 -0.654321
# 3    2018-11-01 08:00:00+05:30 -0.023948 -0.657246
# 4    2018-11-01 09:00:00+05:30  0.082768 -0.655297
# ...                        ...       ...       ...
# 8660 2019-10-28 01:00:00+05:30  0.265285  0.101039
# 8661 2019-10-28 02:00:00+05:30  0.263912  0.169967
# 8662 2019-10-28 03:00:00+05:30  0.251105  0.197763
# 8663 2019-10-28 04:00:00+05:30  0.259464  0.258050
# 8664 2019-10-28 05:00:00+05:30  0.324512  0.359392
#
# [8665 rows x 3 columns]

# %%
def plot_sensors(df):
  
  sensorsName = [idx for idx in super_df['NAME'].unique() if pd.notna(idx)]
  
  for id in sensorsName:
    aux = super_df[super_df['NAME'] == id] 
    st = aux.groupby(pd.Grouper(key='LASTUPDATEDATETIME', freq ='1H'))[['PM2_MAX', 'PM2_MIN']].agg('mean').reset_index()

    plot_df(st, x=st[['LASTUPDATEDATETIME']], y=st[['PM2_MIN']],title=' {} - RTE 01/11/2018 - 28/10/2019'.format(id))
    plt.show

# %%
plot_sensors(super_df)

# %%
#super_df.drop(index= super_df[super_df['NAME'] == ['BopodiSquare_65', 'Bopodi Square_65', 'Bopadi_Square_60']] )
aux = super_df[super_df['NAME'] == 'Bopadi_Square_60'] 
aux[['LASTUPDATEDATETIME', 'PM2_MAX']]
# Out:
#           LASTUPDATEDATETIME   PM2_MAX
# 0  2018-11-14 16:26:54+05:30  0.803892
# 1  2018-11-14 16:11:11+05:30       NaN
# 2  2018-11-14 15:56:11+05:30       NaN
# 3  2018-11-14 15:41:14+05:30       NaN
# 4  2018-11-14 15:26:11+05:30       NaN
# 5  2018-11-14 15:11:13+05:30       NaN
# 6  2018-11-14 14:56:11+05:30       NaN
# 7  2018-11-14 14:41:11+05:30       NaN
# 8  2018-11-14 14:26:13+05:30       NaN
# 9  2018-11-14 14:11:11+05:30       NaN
# 10 2018-11-14 13:56:12+05:30       NaN
# 11 2018-11-14 13:41:11+05:30       NaN
# 12 2018-11-14 13:26:11+05:30       NaN
# 13 2018-11-14 13:11:11+05:30       NaN
# 14 2018-11-14 12:56:12+05:30       NaN
# 15 2018-11-14 12:26:11+05:30       NaN
# 16 2018-11-14 12:11:11+05:30       NaN
# 17 2018-11-14 11:56:12+05:30       NaN
# 18 2018-11-14 10:17:52+05:30  5.694371
# 19 2018-11-14 09:47:02+05:30  5.694371
# 20 2018-11-14 09:32:10+05:30  5.694371
# 21 2018-11-14 09:16:54+05:30  5.694371
# 22 2018-11-14 09:01:54+05:30  5.694371
# ...

# %% [markdown]
# # Matrix Factorization

# %%
import numpy as np

class MF():

    def __init__(self, R, K, alpha, beta, iterations):
        """
        Perform matrix factorization to predict empty
        entries in a matrix.

        Arguments
        - R (ndarray)   : user-item rating matrix
        - K (int)       : number of latent dimensions
        - alpha (float) : learning rate
        - beta (float)  : regularization parameter
        """

        self.R = R
        self.num_users, self.num_items = R.shape
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations

    def train(self):
        # Initialize user and item latent feature matrice
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))

        # Initialize the biases
        self.b_u = np.zeros(self.num_users)
        self.b_i = np.zeros(self.num_items)
        self.b = np.mean(self.R[np.where(self.R != 0)])

        # Create a list of training samples
        self.samples = [
            (i, j, self.R[i, j])
            for i in range(self.num_users)
            for j in range(self.num_items)
            if self.R[i, j] > 0
        ]

        # Perform stochastic gradient descent for number of iterations
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            self.sgd()
            mse = self.mse()
            training_process.append((i, mse))
            if (i+1) % 10 == 0:
                print("Iteration: %d ; error = %.4f" % (i+1, mse))

        return training_process

    def mse(self):
        """
        A function to compute the total mean square error
        """
        xs, ys = self.R.nonzero()
        predicted = self.full_matrix()
        error = 0
        for x, y in zip(xs, ys):
            error += pow(self.R[x, y] - predicted[x, y], 2)
        return np.sqrt(error)

    def sgd(self):
        """
        Perform stochastic graident descent
        """
        for i, j, r in self.samples:
            # Computer prediction and error
            prediction = self.get_rating(i, j)
            e = (r - prediction)

            # Update biases
            self.b_u[i] += self.alpha * (e - self.beta * self.b_u[i])
            self.b_i[j] += self.alpha * (e - self.beta * self.b_i[j])

            # Update user and item latent feature matrices
            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i,:])
            self.Q[j, :] += self.alpha * (e * self.P[i, :] - self.beta * self.Q[j,:])

    def get_rating(self, i, j):
        """
        Get the predicted rating of user i and item j
        """
        prediction = self.b + self.b_u[i] + self.b_i[j] + self.P[i, :].dot(self.Q[j, :].T)
        return prediction

    def full_matrix(self):
        """
        Computer the full matrix using the resultant biases, P and Q
        """
        return self.b + self.b_u[:,np.newaxis] + self.b_i[np.newaxis:,] + self.P.dot(self.Q.T)

# %%
R = np.array([
    [5, 3, 0, 1],
    [4, 0, 0, 1],
    [1, 1, 0, 5],
    [1, 0, 0, 4],
    [0, 1, 5, 4],
])

# %%
type(copy_df)
c = copy_df.to_numpy()

# %%
np.isnan(c)
# Out:
# array([[False, False, False, ..., False,  True,  True],
#        [False, False, False, ..., False,  True,  True],
#        [False, False, False, ..., False,  True,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
mf = MF(c, K=2, alpha=0.1, beta=0.01, iterations=5)
mf

# %%
np.isnan(mf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-36ffcdfce8b4> in <module>()
# ----> 1 np.isnan(mf)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
training_process = mf.train()
print()
print("P x Q:")
print(mf.full_matrix())
print()
print("Global bias:")
print(mf.b)
print()
print("User bias:")
print(mf.b_u)
print()
print("Item bias:")
print(mf.b_i)
# Out:
# P x Q:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
#
# Global bias:
# nan
#
# User bias:
# [ 0. nan nan ... nan nan nan]
#
# Item bias:
# [nan nan nan nan nan nan nan nan nan nan nan]
