# %%
 # !git clone https://github.com/iskandr/fancyimpute.git
# Out:
# Cloning into 'fancyimpute'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 1055 (delta 3), reused 0 (delta 0), pack-reused 1041
# Receiving objects: 100% (1055/1055), 269.14 KiB | 14.17 MiB/s, done.
# Resolving deltas: 100% (711/711), done.

# %% [markdown]
# # Functions

# %%
# %cd /content/fancyimpute/test/
# Out:
# /content/fancyimpute/test

# %%
from low_rank_data import XY, XY_incomplete, missing_mask
from common import reconstruction_error

# %%
XY_incomplete
# Out:
# array([[ 1.00774827e+00, -1.01714427e-01, -1.53210598e-01, ...,
#          1.64950051e+00,             nan,             nan],
#        [            nan,  2.46376640e+00, -1.85186829e+00, ...,
#                     nan,  4.04929204e+00, -2.61363564e+00],
#        [ 2.11851851e-03, -2.65051327e-01,  5.63238148e-01, ...,
#          6.00697444e-02,             nan,             nan],
#        ...,
#        [            nan, -8.10230032e-01,  5.10798189e-01, ...,
#                     nan,             nan,  8.82066311e-01],
#        [-1.48060332e+00,             nan, -2.64835435e+00, ...,
#         -8.73605586e-01,             nan,  2.04854295e+00],
#        [ 7.65004263e-01, -1.28139753e+00,  1.53529536e+00, ...,
#         -1.05924789e-01, -1.06026932e-01,  3.34232762e-01]])

# %%
# %cd /content/fancyimpute/fancyimpute/
# Out:
# /content/fancyimpute/fancyimpute

# %%
# !apt-get install python3-nose
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pkg-resources
# Suggested packages:
#   python-nose-doc python3-setuptools
# The following NEW packages will be installed:
#   python3-nose python3-pkg-resources
# 0 upgraded, 2 newly installed, 0 to remove and 16 not upgraded.
# Need to get 214 kB of archives.
# After this operation, 1,086 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-nose all 1.3.7-3 [115 kB]
# Fetched 214 kB in 1s (222 kB/s)
# Selecting previously unselected package python3-pkg-resources.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-nose.
# Preparing to unpack .../python3-nose_1.3.7-3_all.deb ...
# Unpacking python3-nose (1.3.7-3) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up python3-nose (1.3.7-3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
import pandas as pd
import os
import numpy as np
import warnings
import logging
import importlib
from sklearn.utils import check_array
from nose.tools import eq_

from fancyimpute.knn import KNN


from keras import regularizers
from keras.callbacks import EarlyStopping
from keras.layers import Input
from keras.models import Model
from sklearn.utils import shuffle, check_array

from scaler import Scaler
from keras_models import KerasMatrixFactorizer


#import required packages
from sklearn import neighbors
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
def import_from(module, name):
    '''
    usage example:
    grid = import_from('sklearn.model_selection', 'GridSearchCV')
    is equivalent to:
    from sklearn.model_selection import GridSearchV as grid
    '''
    module = importlib.import_module(module)
    return getattr(module, name)

# %%
def generate_random_column_samples(column):
    col_mask = np.isnan(column)
    n_missing = np.sum(col_mask)
    if n_missing == len(column):
        logging.warn("No observed values in column")
        return np.zeros_like(column)

    mean = np.nanmean(column)
    std = np.nanstd(column)

    if np.isclose(std, 0):
        return np.array([mean] * n_missing)
    else:
        return np.random.randn(n_missing) * std + mean

# %%
class Solver(object):
    def __init__(
            self,
            fill_method="zero",
            min_value=None,
            max_value=None,
            normalizer=None):
        self.fill_method = fill_method
        self.min_value = min_value
        self.max_value = max_value
        self.normalizer = normalizer

    def __repr__(self):
        return str(self)

    def __str__(self):
        field_list = []
        for (k, v) in sorted(self.__dict__.items()):
            if v is None or isinstance(v, (float, int)):
                field_list.append("%s=%s" % (k, v))
            elif isinstance(v, str):
                field_list.append("%s='%s'" % (k, v))
        return "%s(%s)" % (
            self.__class__.__name__,
            ", ".join(field_list))

    def _check_input(self, X):
        if len(X.shape) != 2:
            raise ValueError("Expected 2d matrix, got %s array" % (X.shape,))

    def _check_missing_value_mask(self, missing):
        if not missing.any():
            warnings.simplefilter("always")
            warnings.warn("Input matrix is not missing any values")
        if missing.all():
            raise ValueError("Input matrix must have some non-missing values")

    def _fill_columns_with_fn(self, X, missing_mask, col_fn):
        for col_idx in range(X.shape[1]):
            missing_col = missing_mask[:, col_idx]
            n_missing = missing_col.sum()
            if n_missing == 0:
                continue
            col_data = X[:, col_idx]
            fill_values = col_fn(col_data)
            if np.all(np.isnan(fill_values)):
                fill_values = 0
            X[missing_col, col_idx] = fill_values

    def fill(
            self,
            X,
            missing_mask,
            fill_method=None,
            inplace=False):
        """
        Parameters
        ----------
        X : np.array
            Data array containing NaN entries

        missing_mask : np.array
            Boolean array indicating where NaN entries are

        fill_method : str
            "zero": fill missing entries with zeros
            "mean": fill with column means
            "median" : fill with column medians
            "min": fill with min value per column
            "random": fill with gaussian samples according to mean/std of column

        inplace : bool
            Modify matrix or fill a copy
        """
        X = check_array(X, force_all_finite=False)

        if not inplace:
            X = X.copy()

        if not fill_method:
            fill_method = self.fill_method

        if fill_method not in ("zero", "mean", "median", "min", "random"):
            raise ValueError("Invalid fill method: '%s'" % (fill_method))
        elif fill_method == "zero":
            # replace NaN's with 0
            X[missing_mask] = 0
        elif fill_method == "mean":
            self._fill_columns_with_fn(X, missing_mask, np.nanmean)
        elif fill_method == "median":
            self._fill_columns_with_fn(X, missing_mask, np.nanmedian)
        elif fill_method == "min":
            self._fill_columns_with_fn(X, missing_mask, np.nanmin)
        elif fill_method == "random":
            self._fill_columns_with_fn(
                X,
                missing_mask,
                col_fn=generate_random_column_samples)
        return X

    def prepare_input_data(self, X):
        """
        Check to make sure that the input matrix and its mask of missing
        values are valid. Returns X and missing mask.
        """
        X = check_array(X, force_all_finite=False)
        if X.dtype != "f" and X.dtype != "d":
            X = X.astype(float)

        self._check_input(X)
        missing_mask = np.isnan(X)
        self._check_missing_value_mask(missing_mask)
        return X, missing_mask

    def clip(self, X):
        """
        Clip values to fall within any global or column-wise min/max constraints
        """
        X = np.asarray(X)
        if self.min_value is not None:
            X[X < self.min_value] = self.min_value
        if self.max_value is not None:
            X[X > self.max_value] = self.max_value
        return X

    def project_result(self, X):
        """
        First undo normalization and then clip to the user-specified min/max
        range.
        """
        X = np.asarray(X)
        if self.normalizer is not None:
            X = self.normalizer.inverse_transform(X)
        return self.clip(X)

    def solve(self, X, missing_mask):
        """
        Given an initialized matrix X and a mask of where its missing values
        had been, return a completion of X.
        """
        raise ValueError("%s.solve not yet implemented!" % (
            self.__class__.__name__,))

    def fit_transform(self, X, y=None):
        """
        Fit the imputer and then transform input `X`

        Note: all imputations should have a `fit_transform` method,
        but only some (like IterativeImputer in sklearn) also support inductive
        mode using `fit` or `fit_transform` on `X_train` and then `transform`
        on new `X_test`.
        """
        X_original, missing_mask = self.prepare_input_data(X)
        observed_mask = ~missing_mask
        X = X_original.copy()
        if self.normalizer is not None:
            X = self.normalizer.fit_transform(X)
        X_filled = self.fill(X, missing_mask, inplace=True)
        if not isinstance(X_filled, np.ndarray):
            raise TypeError(
                "Expected %s.fill() to return NumPy array but got %s" % (
                    self.__class__.__name__,
                    type(X_filled)))

        X_result = self.solve(X_filled, missing_mask)
        if not isinstance(X_result, np.ndarray):
            raise TypeError(
                "Expected %s.solve() to return NumPy array but got %s" % (
                    self.__class__.__name__,
                    type(X_result)))

        X_result = self.project_result(X=X_result)
        X_result[observed_mask] = X_original[observed_mask]
        return X_result

    def fit(self, X, y=None):
        """
        Fit the imputer on input `X`.

        Note: all imputations should have a `fit_transform` method,
        but only some (like IterativeImputer in sklearn) also support inductive
        mode using `fit` or `fit_transform` on `X_train` and then `transform`
        on new `X_test`.
        """
        raise ValueError(
            "%s.fit not implemented! This imputation algorithm likely "
            "doesn't support inductive mode. Only fit_transform is "
            "supported at this time." % (
                self.__class__.__name__,))

    def transform(self, X, y=None):
        """
        Transform input `X`.

        Note: all imputations should have a `fit_transform` method,
        but only some (like IterativeImputer in sklearn) also support inductive
        mode using `fit` or `fit_transform` on `X_train` and then `transform`
        on new `X_test`.
        """
        raise ValueError(
            "%s.transform not implemented! This imputation algorithm likely "
            "doesn't support inductive mode. Only %s.fit_transform is "
            "supported at this time." % (
                self.__class__.__name__, self.__class__.__name__))

# %%
class MatrixFactorization(Solver):
    """
    Given an incomplete (m,n) matrix X, factorize it into
    U, V where U.shape = (m, k) and V.shape = (k, n).

    The U, V are found by minimizing the difference between U.dot.V and
    X at the observed entries along with a sparsity penalty for U and an
    L2 penalty for V.
    """

    def __init__(
            self,
            rank=10,
            learning_rate=0.001,
            epochs=10000,
            patience=5,
            l2_penalty=1e-5,
            use_bias=True,
            min_improvement=0.001,
            optimization_algorithm="Adam",
            loss='mse',
            validation_frac=0.1,
            min_value=None,
            max_value=None,
            normalizer=Scaler(),
            verbose=True):
        Solver.__init__(
            self,
            min_value=min_value,
            max_value=max_value,
            normalizer=normalizer)
        self.rank = rank
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.patience = patience
        self.l2_penalty = l2_penalty
        self.use_bias = use_bias
        self.optimization_algorithm = optimization_algorithm
        self.loss = loss
        self.validation_frac = validation_frac
        self.min_improvement = min_improvement
        self.normalizer = normalizer
        self.verbose = verbose

    def solve(self, X, missing_mask):
        X = check_array(X, force_all_finite=False)

        # shape data to fit into keras model
        (n_samples, n_features) = X.shape
        observed_mask = ~missing_mask
        missing_mask_flat = missing_mask.flatten()
        observed_mask_flat = observed_mask.flatten()

        columns, rows = np.meshgrid(np.arange(n_features), np.arange(n_samples))

        # training data
        i_tr = rows.flatten()[observed_mask_flat]
        j_tr = columns.flatten()[observed_mask_flat]
        ij_tr = np.vstack([i_tr, j_tr]).T  # input to factorizer
        y_tr = X.flatten()[observed_mask_flat]  # output of factorizer
        ij_tr, y_tr = shuffle(ij_tr, y_tr)

        # make a keras model
        main_input = Input(shape=(2,), dtype='int32')
        embed = KerasMatrixFactorizer(
            rank=self.rank,
            input_dim_i=n_samples,
            input_dim_j=n_features,
            embeddings_regularizer=regularizers.l2(self.l2_penalty),
            use_bias=self.use_bias
        )(main_input)
        model = Model(inputs=main_input, outputs=embed)
        optimizer = import_from(
            'keras.optimizers', self.optimization_algorithm
        )(lr=self.learning_rate)
        model.compile(optimizer=optimizer, loss=self.loss)
        callbacks = [EarlyStopping(patience=self.patience, min_delta=self.min_improvement)]
        model.fit(
            ij_tr,
            y_tr,
            batch_size=int(len(y_tr) * (1 - self.validation_frac)),
            epochs=self.epochs,
            validation_split=self.validation_frac,
            callbacks=callbacks,
            shuffle=True,
            verbose=self.verbose
        )

        # reassemble the original X
        i_ts = rows.flatten()[missing_mask_flat]
        j_ts = columns.flatten()[missing_mask_flat]
        ij_ts = np.vstack([i_ts, j_ts]).T  # input to factorizer
        X[i_ts, j_ts] = model.predict(ij_ts).T[0]

        return X

# %% [markdown]
# # Performance Model

# %%
def test_matrix_factorization_with_low_rank_random_matrix():
    solver = MatrixFactorization(
        learning_rate=0.01,
        rank=3,
        l2_penalty=0,
        min_improvement=1e-6)
    #print(solver)
    XY_completed = solver.fit_transform(XY_incomplete)
    #print(XY_completed)
    _, missing_mae = reconstruction_error(
        XY,
        XY_completed,
        missing_mask,
        name="MatrixFactorization")
    assert missing_mae < 0.1, "Error too high!"
    return XY_completed, solver

# %%
X_filled = test_matrix_factorization_with_low_rank_random_matrix()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 2612/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 4.5226e-05 - val_loss: 0.0558
# Epoch 2613/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 4.5263e-05 - val_loss: 0.0557
# Epoch 2614/10000
# 1/1 [==============================] - 0s 82ms/step - loss: 4.5319e-05 - val_loss: 0.0558
# Epoch 2615/10000
# 1/1 [==============================] - 0s 91ms/step - loss: 4.5323e-05 - val_loss: 0.0557
# Epoch 2616/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 4.5345e-05 - val_loss: 0.0558
# Epoch 2617/10000
# 1/1 [==============================] - 0s 80ms/step - loss: 4.5316e-05 - val_loss: 0.0557
# Epoch 2618/10000
# 1/1 [==============================] - 0s 166ms/step - loss: 4.5306e-05 - val_loss: 0.0558
# Epoch 2619/10000
# 1/1 [==============================] - 0s 77ms/step - loss: 4.5243e-05 - val_loss: 0.0557
# Epoch 2620/10000
# 1/1 [==============================] - 0s 81ms/step - loss: 4.5201e-05 - val_loss: 0.0557
# Epoch 2621/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 4.5106e-05 - val_loss: 0.0557
# Epoch 2622/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 4.5032e-05 - val_loss: 0.0557
# Epoch 2623/10000
# 1/1 [==============================] - 0s 88ms/step - loss: 4.4906e-05 - val_loss: 0.0557
# Epoch 2624/10000
# 1/1 [==============================] - 0s 93ms/step - loss: 4.4801e-05 - val_loss: 0.0557
# Epoch 2625/10000
# 1/1 [==============================] - 0s 80ms/step - loss: 4.4645e-05 - val_loss: 0.0557
# Epoch 2626/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 4.4511e-05 - val_loss: 0.0557
# Epoch 2627/10000
# 1/1 [==============================] - 0s 185ms/step - loss: 4.4327e-05 - val_loss: 0.0557
# Epoch 2628/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 4.4165e-05 - val_loss: 0.0557
# Epoch 2629/10000
# 1/1 [==============================] - 0s 90ms/step - loss: 4.3954e-05 - val_loss: 0.0557
# Epoch 2630/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 4.3767e-05 - val_loss: 0.0557
# Epoch 2631/10000
# 1/1 [==============================] - 0s 83ms/step - loss: 4.3532e-05 - val_loss: 0.0557
# Epoch 2632/10000
# 1/1 [==============================] - 0s 84ms/step - loss:
10000
# 1/1 [==============================] - 0s 86ms/step - loss: 4.1461e-05 - val_loss: 0.0502
# Epoch 5109/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 4.1063e-05 - val_loss: 0.0502
# First 10 reconstructed values:
#   (0,3)  0.1922 ~= 0.2256
#   (0,4)  -1.2261 ~= -1.2296
#   (0,8)  0.2605 ~= 0.2568
#   (0,9)  -1.6903 ~= -1.6862
#   (1,0)  -2.8922 ~= -2.8786
#   (1,6)  0.5202 ~= 0.5203
#   (1,7)  -1.0657 ~= -1.0554
#   (2,3)  -0.5472 ~= -0.5312
#   (2,8)  1.1723 ~= 1.1772
#   (2,9)  -0.9734 ~= -0.9683
# MatrixFactorization MSE: 0.1246, MAE: 0.0544

# %% [markdown]
# # Iterative Super Vector Machine

# %%
from fancyimpute import IterativeSVD

def test_iterative_svd_with_low_rank_random_matrix():
    solver = IterativeSVD(rank=3)
    XY_completed = solver.fit_transform(XY_incomplete)
    _, missing_mae = reconstruction_error(
        XY,
        XY_completed,
        missing_mask,
        name="IterativeSVD")
    assert missing_mae < 0.1, "Error too high!"


X_filled_svd = test_iterative_svd_with_low_rank_random_matrix()
# Out:
# [IterativeSVD] Iter 1: observed MAE=0.729475
# [IterativeSVD] Iter 2: observed MAE=0.414636
# [IterativeSVD] Iter 3: observed MAE=0.135410
# [IterativeSVD] Iter 4: observed MAE=0.078199
# [IterativeSVD] Iter 5: observed MAE=0.052945
# [IterativeSVD] Iter 6: observed MAE=0.039155
# [IterativeSVD] Iter 7: observed MAE=0.030250
# [IterativeSVD] Iter 8: observed MAE=0.024050
# [IterativeSVD] Iter 9: observed MAE=0.019528
# [IterativeSVD] Iter 10: observed MAE=0.016155
# [IterativeSVD] Iter 11: observed MAE=0.013570
# [IterativeSVD] Iter 12: observed MAE=0.011550
# [IterativeSVD] Iter 13: observed MAE=0.009947
# [IterativeSVD] Iter 14: observed MAE=0.008645
# [IterativeSVD] Iter 15: observed MAE=0.007572
# [IterativeSVD] Iter 16: observed MAE=0.006677
# [IterativeSVD] Iter 17: observed MAE=0.005925
# [IterativeSVD] Iter 18: observed MAE=0.005290
# [IterativeSVD] Iter 19: observed MAE=0.004748
# [IterativeSVD] Iter 20: observed MAE=0.004283
# [IterativeSVD] Iter 21: observed MAE=0.003884
# [IterativeSVD] Iter 22: observed MAE=0.003538
# [IterativeSVD] Iter 23: observed MAE=0.003237
# [IterativeSVD] Iter 24: observed MAE=0.002973
# [IterativeSVD] Iter 25: observed MAE=0.002741
# First 10 reconstructed values:
#   (0,3)  0.1922 ~= 0.8456
#   (0,4)  -1.2261 ~= -0.6970
#   (0,8)  0.2605 ~= -0.6095
#   (0,9)  -1.6903 ~= -1.0189
#   (1,0)  -2.8922 ~= -2.8975
#   (1,6)  0.5202 ~= 0.5227
#   (1,7)  -1.0657 ~= -1.0681
#   (2,3)  -0.5472 ~= -0.5217
#   (2,8)  1.1723 ~= 1.1445
#   (2,9)  -0.9734 ~= -0.9530
# IterativeSVD MSE: 0.0161, MAE: 0.0305

# %%
def test_knn():
    # get a baseline error from just zero-filling the missing entries
    sad_zero_fill = np.sum(np.abs(XY[missing_mask]))
    mad_zero_fill = sad_zero_fill / missing_mask.sum()
    print("MAD zero-fill = ", mad_zero_fill)
    for k in [5, 15, 30]:
        print("-- k=", k)
        XY_completed = KNN(k).fit_transform(XY_incomplete)
        mask = np.isfinite(XY_completed)
        eq_((~mask).sum(), 0)
        diff = (XY_completed - XY)[missing_mask]
        sad = np.sum(np.abs(diff))
        mad = sad / missing_mask.sum()
        print("Mean absolute error", mad)
        # knnImpute should be at least twice as good as just zero fill
        assert mad <= (mad_zero_fill / 2.0), \
            "Expected knnImpute to be 2x better than zeroFill (%f) but got MAD=%f" % (
                mad_zero_fill,
                mad)

# %%
X_filled_knn = test_knn()
# Out:
# MAD zero-fill =  1.1593901478619075
# -- k= 5
# Imputing row 1/500 with 4 missing, elapsed time: 0.063
# Imputing row 101/500 with 4 missing, elapsed time: 0.070
# Imputing row 201/500 with 4 missing, elapsed time: 0.078
# Imputing row 301/500 with 3 missing, elapsed time: 0.085
# Imputing row 401/500 with 4 missing, elapsed time: 0.093
# Mean absolute error 0.5122055775761624
# -- k= 15
# Imputing row 1/500 with 4 missing, elapsed time: 0.053
# Imputing row 101/500 with 4 missing, elapsed time: 0.059
# Imputing row 201/500 with 4 missing, elapsed time: 0.065
# Imputing row 301/500 with 3 missing, elapsed time: 0.069
# Imputing row 401/500 with 4 missing, elapsed time: 0.077
# Mean absolute error 0.4832376639047212
# -- k= 30
# Imputing row 1/500 with 4 missing, elapsed time: 0.058
# Imputing row 101/500 with 4 missing, elapsed time: 0.065
# Imputing row 201/500 with 4 missing, elapsed time: 0.073
# Imputing row 301/500 with 3 missing, elapsed time: 0.081
# Imputing row 401/500 with 4 missing, elapsed time: 0.089
# Mean absolute error 0.4893717993097289

# %% [markdown]
# # Handling NAN values in quality air sensors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# path = '/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/Data_csv/DataIlias/'
# pathdir  = np.array(os.listdir(path))
# csv_file_list = {}


# for dirname in pathdir:
#   csv_file_list[dirname] = pd.read_csv(path + dirname, header=0, index_col=0).reset_index()

# %%
# super_df = pd.concat(csv_file_list.values(), keys=csv_file_list.keys())
# super_df.reset_index(inplace=True)
# super_df.rename(columns={'level_0': 'Sensor'}, inplace=True)
# super_df
# Out:
#                Sensor  level_1        Date  Hour  PM2_MIN  PM2_MAX  PM2_MOY
# 0      sensor16v2.csv        0  2019-08-28     0      400      400      400
# 1      sensor16v2.csv        1  2019-08-28     1      400      400      400
# 2      sensor16v2.csv        2  2019-08-28     2      400      400      400
# 3      sensor16v2.csv        3  2019-08-28     3      400      400      400
# 4      sensor16v2.csv        4  2019-08-28     4      400      400      400
# ...               ...      ...         ...   ...      ...      ...      ...
# 63979  sensor59v2.csv     1483  2019-10-28    19      400      400      400
# 63980  sensor59v2.csv     1484  2019-10-28    20      400      400      400
# 63981  sensor59v2.csv     1485  2019-10-28    21      400      400      400
# 63982  sensor59v2.csv     1486  2019-10-28    22      400      400      400
# 63983  sensor59v2.csv     1487  2019-10-28    23      400      400      400
#
# [63984 rows x 7 columns]

# %%
# super_df.drop(columns=['level_1'], inplace=True)

# %%
# super_df[super_df[['PM2_MIN', 'PM2_MAX', 'PM2_MOY']] == 400] = np.nan

# %%
# super_df.to_csv('/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/Data_csv/superdfi.csv')

# %%
super_df = pd.read_csv('/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/air-polution-sensor/data/superdfi.csv', header=0, index_col=0)

# %%
filldf = super_df.copy(deep=True)
filldf.drop(columns=['Sensor','Date', 'Hour'], inplace=True)

# %%
X_incomplete = filldf.to_numpy()

# %%
solverSensors = MatrixFactorization(
        learning_rate=0.01,
        rank=3,
        l2_penalty=0,
        min_improvement=1e-6)

# %%
X_completed = solverSensors.fit_transform(X_incomplete)
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 1s 973ms/step - loss: 1.4647 - val_loss: 1.4492
# Epoch 2/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.4154 - val_loss: 1.4244
# Epoch 3/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3805 - val_loss: 1.4027
# Epoch 4/10000
# 1/1 [==============================] - 0s 184ms/step - loss: 1.3497 - val_loss: 1.3819
# Epoch 5/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 1.3202 - val_loss: 1.3613
# Epoch 6/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 1.2914 - val_loss: 1.3409
# Epoch 7/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.2630 - val_loss: 1.3205
# Epoch 8/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2351 - val_loss: 1.3003
# Epoch 9/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2077 - val_loss: 1.2801
# Epoch 10/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1808 - val_loss: 1.2601
# Epoch 11/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1545 - val_loss: 1.2402
# Epoch 12/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1288 - val_loss: 1.2205
# Epoch 13/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.1039 - val_loss: 1.2011
# Epoch 14/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0796 - val_loss: 1.1818
# Epoch 15/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0560 - val_loss: 1.1628
# Epoch 16/10000
# 1/1 [==============================] - 0s 163ms/step - loss: 1.0332 - val_loss: 1.1440
# Epoch 17/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0110 - val_loss: 1.1255
# Epoch 18/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.9896 - val_loss: 1.1072
# Epoch 19/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.9688 - val_loss: 1.0893
# Epoch 20/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.9488 - val_loss: 1.0715
# Epoch 21/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9293 - val_loss: 1.0541
# Epoch 22/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.9105 - val_loss: 1.0368
# Epoch 23/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.8923 - val_loss: 1.0199
# Epoch 24/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.8747 - val_loss: 1.0031
# Epoch 25/10000
# 1/1 [==============================] - 0s 159ms/step - loss: 0.8576 - val_loss: 0.9866
# Epoch 26/10000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.8410 - val_loss: 0.9703
# Epoch 27/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.8249 - val_loss: 0.9543
# Epoch 28/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.8093 - val_loss: 0.9384
# Epoch 29/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7941 - val_loss: 0.9228
# Epoch 30/10000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.7793 - val_loss: 0.9073
# Epoch 31/10000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.7649 - val_loss: 0.8921
# Epoch 32/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.7509 - val_loss: 0.8770
# Epoch 33/10000
# 1/1 [==============================] - 0s 162ms/step - loss: 0.7373 - val_loss: 0.8622
# Epoch 34/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7240 - val_loss: 0.8475
# Epoch 35/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7110 - val_loss: 0.8330
# Epoch 36/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6983 - val_loss: 0.8187
# Epoch 37/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6859 - val_loss: 0.8045
# Epoch 38/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6737 - val_loss: 0.7905
# Epoch 39/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6619 - val_loss: 0.7769
# Epoch 40/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6502 - val_loss: 0.7630
# Epoch 41/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.
10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0790 - val_loss: 0.1357
# Epoch 156/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0778 - val_loss: 0.1347
# Epoch 157/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0767 - val_loss: 0.1338
# Epoch 158/10000
# 1/1 [==============================] - 0s 175ms/step - loss: 0.0756 - val_loss: 0.1329
# Epoch 159/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0746 - val_loss: 0.1320
# Epoch 160/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0735 - val_loss: 0.1311
# Epoch 161/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0725 - val_loss: 0.1303
# Epoch 162/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0715 - val_loss: 0.1295
# Epoch 163/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0706 - val_loss: 0.1287
# Epoch 164/10000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0696 - val_loss: 0.1279
# Epoch 165/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0687 - val_loss: 0.1272
# Epoch 166/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0678 - val_loss: 0.1264
# Epoch 167/10000
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0669 - val_loss: 0.1258
# Epoch 168/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0660 - val_loss: 0.1250
# Epoch 169/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0652 - val_loss: 0.1245
# Epoch 170/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0643 - val_loss: 0.1237
# Epoch 171/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0635 - val_loss: 0.1232
# Epoch 172/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0627 - val_loss: 0.1224
# Epoch 173/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0619 - val_loss: 0.1221
# Epoch 174/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0612 - val_loss: 0.1212
# Epoch 175/10000
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0604 - val_loss: 0.1210
# Epoch 176/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0597 - val_loss: 0.1200
# Epoch 177/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0590 - val_loss: 0.1201
# Epoch 178/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0583 - val_loss: 0.1188
# Epoch 179/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0577 - val_loss: 0.1194
# Epoch 180/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0571 - val_loss: 0.1177
# Epoch 181/10000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0565 - val_loss: 0.1189
# Epoch 182/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0560 - val_loss: 0.1168
# Epoch 183/10000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0555 - val_loss: 0.1185
# Epoch 184/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0550 - val_loss: 0.1159
# Epoch 185/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0545 - val_loss: 0.1177
# Epoch 186/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0539 - val_loss: 0.1151
# Epoch 187/10000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0533 - val_loss: 0.1165
# Epoch 188/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0526 - val_loss: 0.1142
# Epoch 189/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0519 - val_loss: 0.1153
# Epoch 190/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0512 - val_loss: 0.1135
# Epoch 191/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0506 - val_loss: 0.1142
# Epoch 192/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0500 - val_loss: 0.1129
# Epoch 193/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0494 - val_loss: 0.1132
# Epoch 194/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0489 - val_loss: 0.1122
# Epoch 195/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0484 - val_loss: 0.1124
# Epoch 196/10000
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0479 - val_loss: 0.1117
# Epoch 197/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0474 - val_loss: 0.1117
# Epoch 198/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0469 - val_loss: 0.1111
# Epoch 199/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0464 - val_loss: 0.1111
# Epoch 200/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0460 - val_loss: 0.1106
# Epoch 201/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0455 - val_loss: 0.1105
# Epoch 202/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0451 - val_loss: 0.1100
# Epoch 203/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0447 - val_loss: 0.1099
# Epoch 204/10000
# 1/1 [==============================] - 0s 175ms/step - loss: 0.0443 - val_loss: 0.1095
# Epoch 205/10000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0439 - val_loss: 0.1094
# Epoch 206/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0435 - val_loss: 0.1091
# Epoch 207/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0431 - val_loss: 0.1089
# Epoch 208/10000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0427 - val_loss: 0.1086
# Epoch 209/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0423 - val_loss: 0.1085
# Epoch 210/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0419 - val_loss: 0.1082
# Epoch 211/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0416 - val_loss: 0.1081
# Epoch 212/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0412 - val_loss: 0.1078
# Epoch 213/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0409 - val_loss: 0.1077
# Epoch 214/10000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0405 - val_loss: 0.1075
# Epoch 215/10000
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0402 - val_loss: 0.1073
# Epoch 216/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0399 - val_loss: 0.1071
# Epoch 217/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0395 - val_loss: 0.1070
# Epoch 218/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0392 - val_loss: 0.1068
# Epoch 219/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0389 - val_loss: 0.1067
# Epoch 220/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0386 - val_loss: 0.1065
# Epoch 221/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0383 - val_loss: 0.1064
# Epoch 222/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0380 - val_loss: 0.1062
# Epoch 223/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0377 - val_loss: 0.1061
# Epoch 224/10000
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0374 - val_loss: 0.1059
# Epoch 225/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0372 - val_loss: 0.1059
# Epoch 226/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0369 - val_loss: 0.1057
# Epoch 227/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0366 - val_loss: 0.1056
# Epoch 228/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0363 - val_loss: 0.1054
# Epoch 229/10000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0361 - val_loss: 0.1054
# Epoch 230/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0358 - val_loss: 0.1052
# Epoch 231/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0356 - val_loss: 0.1052
# Epoch 232/10000
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0353 - val_loss: 0.1050
# Epoch 233/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0351 - val_loss: 0.1050
# Epoch 234/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0349 - val_loss: 0.1049
# Epoch 235/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0346 - val_loss: 0.1049
# Epoch 236/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0344 - val_loss: 0.1047
# Epoch 237/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0342 - val_loss: 0.1047
# Epoch 238/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0340 - val_loss: 0.1045
# Epoch 239/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0338 - val_loss: 0.1046
# Epoch 240/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0335 - val_loss: 0.1044
# Epoch 241/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0333 - val_loss: 0.1045
# Epoch 242/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0331 - val_loss: 0.1042
# Epoch 243/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0329 - val_loss: 0.1044
# Epoch 244/10000
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0327 - val_loss: 0.1041
# Epoch 245/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0325 - val_loss: 0.1043
# Epoch 246/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0324 - val_loss: 0.1040
# Epoch 247/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0322 - val_loss: 0.1043
# Epoch 248/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0320 - val_loss: 0.1038
# Epoch 249/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0318 - val_loss: 0.1043
# Epoch 250/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0317 - val_loss: 0.1037
# Epoch 251/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0315 - val_loss: 0.1043
# Epoch 252/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0314 - val_loss: 0.1036
# Epoch 253/10000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0312 - val_loss: 0.1045
# Epoch 254/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0311 - val_loss: 0.1035
# Epoch 255/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0310 - val_loss: 0.1047
# Epoch 256/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0309 - val_loss: 0.1035
# Epoch 257/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0308 - val_loss: 0.1049
# Epoch 258/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0308 - val_loss: 0.1035
# Epoch 259/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0307 - val_loss: 0.1052
# Epoch 260/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0306 - val_loss: 0.1035
# Epoch 261/10000
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0305 - val_loss: 0.1052

# %%
print(X_incomplete)
print(X_completed)
# Out:
# [[nan nan nan]
#  [nan nan nan]
#  [nan nan nan]
#  ...
#  [nan nan nan]
#  [nan nan nan]
#  [nan nan nan]]
# [[ 17.3611462   24.65436082  20.8906025 ]
#  [ 23.72402051  44.14660158  32.58474362]
#  [  6.3346886   10.49705616   7.84149126]
#  ...
#  [ 70.53606146 110.91280718  90.34005848]
#  [ 39.91364232  61.45073436  50.38389253]
#  [ 57.94142652  86.44004997  72.38476085]]

# %%
super_dfFilled = pd.DataFrame(X_completed, columns = ['PM2_MIN','PM2_MAX','PM2_MOY'])

# %%
super_df.head()
# Out:
#            Sensor        Date  Hour  PM2_MIN  PM2_MAX  PM2_MOY
# 0  sensor16v2.csv  2019-08-28     0      NaN      NaN      NaN
# 1  sensor16v2.csv  2019-08-28     1      NaN      NaN      NaN
# 2  sensor16v2.csv  2019-08-28     2      NaN      NaN      NaN
# 3  sensor16v2.csv  2019-08-28     3      NaN      NaN      NaN
# 4  sensor16v2.csv  2019-08-28     4      NaN      NaN      NaN

# %%
super_dfFilled[['Sensor', 'Date', 'Hour']] = super_df[['Sensor', 'Date', 'Hour']]

# %%
super_dfFilled = super_dfFilled[['Sensor', 'Date', 'Hour', 'PM2_MIN', 'PM2_MAX', 'PM2_MOY']]
super_dfFilled
# Out:
#                Sensor        Date  Hour    PM2_MIN     PM2_MAX     PM2_MOY
# 0      sensor16v2.csv  2019-08-28     0  17.361146   24.654361   20.890603
# 1      sensor16v2.csv  2019-08-28     1  23.724021   44.146602   32.584744
# 2      sensor16v2.csv  2019-08-28     2   6.334689   10.497056    7.841491
# 3      sensor16v2.csv  2019-08-28     3  80.047917  126.959842  103.029719
# 4      sensor16v2.csv  2019-08-28     4  56.158266   82.691930   69.724671
# ...               ...         ...   ...        ...         ...         ...
# 63979  sensor59v2.csv  2019-10-28    19  54.898410   89.304924   71.321650
# 63980  sensor59v2.csv  2019-10-28    20  46.331950   76.160910   60.428250
# 63981  sensor59v2.csv  2019-10-28    21  70.536061  110.912807   90.340058
# 63982  sensor59v2.csv  2019-10-28    22  39.913642   61.450734   50.383893
# 63983  sensor59v2.csv  2019-10-28    23  57.941427   86.440050   72.384761
#
# [63984 rows x 6 columns]

# %%
super_dfFilled.isnull().sum().sum(  )
# Out:
# 0

# %% [markdown]
# # Performance in interval of time series without NAN values

# %%
super_df = pd.read_csv('/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/air-polution-sensor/data/superdfi.csv', header=0, index_col=0)

# %%
#aux = super_df[(super_df['Sensor'] == 'sensor14v2.csv')]
aux = super_df[(super_df['Sensor'] == 'sensor14v2.csv') | (super_df['Sensor'] == 'sensor13v2.csv') | (super_df['Sensor'] == 'sensor12v2.csv') | (super_df['Sensor'] == 'sensor11v2.csv') | (super_df['Sensor'] == 'sensor10v2.csv') | (super_df['Sensor'] == 'sensor9v2.csv') | (super_df['Sensor'] == 'sensor8v2.csv') | (super_df['Sensor'] == 'sensor7v2.csv') ]
#aux =aux.dropna().reset_index()
#aux.isnull().sum().sum()

# %%
aux = pd.pivot_table(data=aux,values='PM2_MOY',index=['Date', 'Hour'],columns= 'Sensor')
aux = aux.dropna()
columnst = aux.columns
indext = aux.index

# %%
aux_arr = aux.to_numpy()
aux_incomplete =  np.copy(aux_arr)
missing_raw_values = np.random.uniform(0, 1, aux_arr.shape)
missing_mask = missing_raw_values < 0.3
missing_mask[0] = False
aux_incomplete[missing_mask] = np.nan

# %%
aux_incomplete = pd.DataFrame(aux_incomplete, columns = columnst, index= indext).reset_index()
auxoriginal = aux_incomplete.copy(deep=True)

# %%
aux_incomplete
# Out:
# Sensor        Date  Hour  ...  sensor8v2.csv  sensor9v2.csv
# 0       2019-08-28    12  ...            4.0           20.0
# 1       2019-08-28    13  ...            4.0            NaN
# 2       2019-08-28    14  ...            4.0           20.0
# 3       2019-08-28    15  ...            4.0           20.0
# 4       2019-08-28    16  ...            4.0           20.0
# ..             ...   ...  ...            ...            ...
# 994     2019-10-27     0  ...           15.0            NaN
# 995     2019-10-27     2  ...           15.0           52.0
# 996     2019-10-27     3  ...           15.0           53.0
# 997     2019-10-27     4  ...           16.0           54.0
# 998     2019-10-27     5  ...           16.0           55.0
#
# [999 rows x 10 columns]

# %%
 df = aux_incomplete.iloc[:, 2:10]

# %%
df= df.fillna(df.interpolate(method='linear'), axis=1)
#aux_incomplete = aux_incomplete.dropna()
arr_completed = df.to_numpy()

# %%
df.isnull().sum()
# Out:
# Sensor
# sensor10v2.csv    0
# sensor11v2.csv    0
# sensor12v2.csv    0
# sensor13v2.csv    0
# sensor14v2.csv    0
# sensor7v2.csv     0
# sensor8v2.csv     0
# sensor9v2.csv     0
# dtype: int64

# %%
rmse, missing_mae = reconstruction_error(
        aux_arr,
        arr_completed,
        missing_mask,
        name="SoftImpute")
# Out:
# First 10 reconstructed values:
#   (1,2)  8.0000 ~= 8.0000
#   (1,4)  11.0000 ~= 11.0000
#   (2,0)  19.0000 ~= 17.0000
#   (3,1)  7.0000 ~= 7.0000
#   (3,5)  21.0000 ~= 21.0000
#   (4,3)  5.0000 ~= 5.0000
#   (4,4)  11.0000 ~= 11.0000
#   (5,3)  5.0000 ~= 5.0000
#   (5,7)  20.0000 ~= 20.0000
#   (6,7)  20.0000 ~= 20.0000
# SoftImpute  RMSE: 4.8861, MAE: 0.4703

# %%
plt.figure(figsize=(20,5))
plt.axis([0,1000, 0, 23])
plt.plot(df['sensor11v2.csv'],'b')
plt.title('Average PM2.5 filled by Linear Interpolation , when the percentaje of missing values equals 25%, sensor 11', size=20)
plt.xlabel('Time',size=18)
plt.ylabel('Average PM2.5',size=18)
# Out:
# Text(0, 0.5, 'Average PM2.5')

# %%
plt.figure(figsize=(20,5))
plt.axis([0,1000, 0, 23])
plt.plot(auxoriginal['sensor11v2.csv'],'r')
plt.title('Original average PM2.5 with a percentaje of missing values equals 25%, sensor 11 ', size=20)
plt.xlabel('Time',size=18)
plt.ylabel('Average PM2.5',size=18)
# Out:
# Text(0, 0.5, 'Average PM2.5')

# %%
def test_matrix_completion():
    solverTestSensors = MatrixFactorization(
        learning_rate=0.001,
        rank=2,
        l2_penalty= 1e-5,
        patience=100,
        validation_frac=0.15,
        min_improvement=1e-6)
    aux_completed = solverTestSensors.fit_transform(aux_incomplete)
    #print(XY_completed)
    _, missing_mae = reconstruction_error(
        aux_arr,
        aux_completed,   
        missing_mask,
        name="MatrixFactorization")
    #assert missing_mae < 0.1, "Error too high!"
    return aux_completed 
aux_completed = test_matrix_completion()
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 2s 2s/step - loss: 1.4315 - val_loss: 1.1472
# Epoch 2/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.4279 - val_loss: 1.1449
# Epoch 3/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.4244 - val_loss: 1.1426
# Epoch 4/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4209 - val_loss: 1.1403
# Epoch 5/10000
# 1/1 [==============================] - 0s 172ms/step - loss: 1.4174 - val_loss: 1.1380
# Epoch 6/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4139 - val_loss: 1.1357
# Epoch 7/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.4105 - val_loss: 1.1335
# Epoch 8/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.4070 - val_loss: 1.1312
# Epoch 9/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.4036 - val_loss: 1.1289
# Epoch 10/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4002 - val_loss: 1.1266
# Epoch 11/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3968 - val_loss: 1.1243
# Epoch 12/10000
# 1/1 [==============================] - 0s 168ms/step - loss: 1.3934 - val_loss: 1.1219
# Epoch 13/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3900 - val_loss: 1.1196
# Epoch 14/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3867 - val_loss: 1.1173
# Epoch 15/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3833 - val_loss: 1.1149
# Epoch 16/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.3800 - val_loss: 1.1126
# Epoch 17/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3767 - val_loss: 1.1102
# Epoch 18/10000
# 1/1 [==============================] - 0s 161ms/step - loss: 1.3734 - val_loss: 1.1079
# Epoch 19/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3701 - val_loss: 1.1056
# Epoch 20/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3668 - val_loss: 1.1032
# Epoch 21/10000
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3636 - val_loss: 1.1009
# Epoch 22/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3603 - val_loss: 1.0986
# Epoch 23/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3571 - val_loss: 1.0963
# Epoch 24/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.3539 - val_loss: 1.0940
# Epoch 25/10000
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3507 - val_loss: 1.0917
# Epoch 26/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3475 - val_loss: 1.0895
# Epoch 27/10000
# 1/1 [==============================] - 0s 166ms/step - loss: 1.3443 - val_loss: 1.0872
# Epoch 28/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.3412 - val_loss: 1.0850
# Epoch 29/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3380 - val_loss: 1.0828
# Epoch 30/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.3349 - val_loss: 1.0806
# Epoch 31/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.3318 - val_loss: 1.0784
# Epoch 32/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.3287 - val_loss: 1.0762
# Epoch 33/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.3256 - val_loss: 1.0740
# Epoch 34/10000
# 1/1 [==============================] - 0s 178ms/step - loss: 1.3226 - val_loss: 1.0719
# Epoch 35/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3195 - val_loss: 1.0697
# Epoch 36/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.3165 - val_loss: 1.0676
# Epoch 37/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.3134 - val_loss: 1.0654
# Epoch 38/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.3104 - val_loss: 1.0633
# Epoch 39/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3074 - val_loss: 1.0612
# Epoch 40/10000
# 1/1 [==============================] - 0s 165ms/step - loss: 1.3044 - val_loss: 1.0591
# Epoch 41/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.3015 - val_loss: 1.0570
# Epoch 42/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2985 - val_loss: 1.0549
# Epoch 43/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2956 - val_loss: 1.0528
# Epoch 44/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2927 - val_loss: 1.0508
# Epoch 45/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2897 - val_loss: 1.0487
# Epoch 46/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.2868 - val_loss: 1.0467
# Epoch 47/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2839 - val_loss: 1.0446
# Epoch 48/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2811 - val_loss: 1.0426
# Epoch 49/10000
# 1/1 [==============================] - 0s 166ms/step - loss: 1.2782 - val_loss: 1.0406
# Epoch 50/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2754 - val_loss: 1.0386
# Epoch 51/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 1.2725 - val_loss: 1.0366
# Epoch 52/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.2697 - val_loss: 1.0346
# Epoch 53/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2669 - val_loss: 1.0327
# Epoch 54/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2641 - val_loss: 1.0307
# Epoch 55/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2613 - val_loss: 1.0288
# Epoch 56/10000
# 1/1 [==============================] - 0s 161ms/step - loss: 1.2586 - val_loss: 1.0268
# Epoch 57/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.2558 - val_loss: 1.0249
# Epoch 58/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2531 - val_loss: 1.0229
# Epoch 59/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2503 - val_loss: 1.0210
# Epoch 60/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2476 - val_loss: 1.0191
# Epoch 61/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2449 - val_loss: 1.0172
# Epoch 62/10000
# 1/1 [==============================] - 0s 164ms/step - loss: 1.2422 - val_loss: 1.0153
# Epoch 63/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2395 - val_loss: 1.0134
# Epoch 64/10000
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2368 - val_loss: 1.0115
# Epoch 65/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2342 - val_loss: 1.0096
# Epoch 66/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.2315 - val_loss: 1.0077
# Epoch 67/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2289 - val_loss: 1.0058
# Epoch 68/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.2263 - val_loss: 1.0040
# Epoch 69/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2237 - val_loss: 1.0021
# Epoch 70/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2211 - val_loss: 1.0003
# Epoch 71/10000
# 1/1 [==============================] - 0s 179ms/step - loss: 1.2185 - val_loss: 0.9984
# Epoch 72/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2159 - val_loss: 0.9966
# Epoch 73/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2133 - val_loss: 0.9948
# Epoch 74/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.2108 - val_loss: 0.9930
# Epoch 75/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.2082 - val_loss: 0.9912
# Epoch 76/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2057 - val_loss: 0.9894
# Epoch 77/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2032 - val_loss: 0.9876
# Epoch 78/10000
# 1/1 [==============================] - 0s 169ms/step - loss: 1.2007 - val_loss: 0.9858
# Epoch 79/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.1982 - val_loss: 0.9841
# Epoch 80/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1957 - val_loss: 0.9823
# Epoch 81/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1932 - val_loss: 0.9806
# Epoch 82/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1907 - val_loss: 0.9788
# Epoch 83/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1883 - val_loss: 0.9771
# Epoch 84/10000
# 1/1 [==============================] - 0s 166ms/step - loss: 1.1858 - val_loss: 0.9753
# Epoch 85/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1834 - val_loss: 0.9736
# Epoch 86/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1810 - val_loss: 0.9719
# Epoch 87/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.1785 - val_loss: 0.9702
# Epoch 88/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1761 - val_loss: 0.9685
# Epoch 89/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1737 - val_loss: 0.9668
# Epoch 90/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1713 - val_loss: 0.9651
# Epoch 91/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1690 - val_loss: 0.9634
# Epoch 92/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1666 - val_loss: 0.9617
# Epoch 93/10000
# 1/1 [==============================] - 0s 178ms/step - loss: 1.1642 - val_loss: 0.9600
# Epoch 94/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1619 - val_loss: 0.9584
# Epoch 95/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.1596 - val_loss: 0.9567
# Epoch 96/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.1572 - val_loss: 0.9550
# Epoch 97/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1549 - val_loss: 0.9534
# Epoch 98/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 1.1526 - val_loss: 0.9518
# Epoch 99/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1503 - val_loss: 0.9501
# Epoch 100/10000
# 1/1 [==============================] - 0s 163ms/step - loss: 1.1480 - val_loss: 0.9485
# Epoch 101/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1457 - val_loss: 0.9469
# Epoch 102/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1435 - val_loss: 0.9453
# Epoch 103/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1412 - val_loss: 0.9437
# Epoch 104/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1389 - val_loss: 0.9421
# Epoch 105/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1367 - val_loss: 0.9405
# Epoch 106/10000
# 1/1 [==============================] - 0s 174ms/step - loss: 1.1345 - val_loss: 0.9389
# Epoch 107/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1322 - val_loss: 0.9373
# Epoch 108/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 1.1300 - val_loss: 0.9357
# Epoch 109/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.1278 - val_loss: 0.9341
# Epoch 110/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1256 - val_loss: 0.9326
# Epoch 111/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 1.1234 - val_loss: 0.9310
# Epoch 112/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1212 - val_loss: 0.9294
# Epoch 113/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1191 - val_loss: 0.9279
# Epoch 114/10000
# 1/1 [==============================] - 0s 167ms/step - loss: 1.1169 - val_loss: 0.9264
# Epoch 115/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.1147 - val_loss: 0.9248
# Epoch 116/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1126 - val_loss: 0.9233
# Epoch 117/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1104 - val_loss: 0.9218
# Epoch 118/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 1.1083 - val_loss: 0.9202
# Epoch 119/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1062 - val_loss: 0.9187
# Epoch 120/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1041 - val_loss: 0.9172
# Epoch 121/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1020 - val_loss: 0.9157
# Epoch 122/10000
# 1/1 [==============================] - 0s 167ms/step - loss: 1.0999 - val_loss: 0.9142
# Epoch 123/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0978 - val_loss: 0.9127
# Epoch 124/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0957 - val_loss: 0.9112
# Epoch 125/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0936 - val_loss: 0.9097
# Epoch 126/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0915 - val_loss: 0.9083
# Epoch 127/10000
# 1/1 [==============================] - 0s 173ms/step - loss: 1.0895 - val_loss: 0.9068
# Epoch 128/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0874 - val_loss: 0.9053
# Epoch 129/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0854 - val_loss: 0.9039
# Epoch 130/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0833 - val_loss: 0.9024
# Epoch 131/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0813 - val_loss: 0.9009
# Epoch 132/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0793 - val_loss: 0.8995
# Epoch 133/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0773 - val_loss: 0.8980
# Epoch 134/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0753 - val_loss: 0.8966
# Epoch 135/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0733 - val_loss: 0.8952
# Epoch 136/10000
# 1/1 [==============================] - 0s 164ms/step - loss: 1.0713 - val_loss: 0.8937
# Epoch 137/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0693 - val_loss: 0.8923
# Epoch 138/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0673 - val_loss: 0.8909
# Epoch 139/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0653 - val_loss: 0.8895
# Epoch 140/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0634 - val_loss: 0.8881
# Epoch 141/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0614 - val_loss: 0.8867
# Epoch 142/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0595 - val_loss: 0.8853
# Epoch 143/10000
# 1/1 [==============================] - 0s 187ms/step - loss: 1.0575 - val_loss: 0.8839
# Epoch 144/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0556 - val_loss: 0.8825
# Epoch 145/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0537 - val_loss: 0.8811
# Epoch 146/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0517 - val_loss: 0.8797
# Epoch 147/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0498 - val_loss: 0.8783
# Epoch 148/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0479 - val_loss: 0.8770
# Epoch 149/10000
# 1/1 [==============================] - 0s 162ms/step - loss: 1.0460 - val_loss: 0.8756
# Epoch 150/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 1.0441 - val_loss: 0.8742
# Epoch 151/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0422 - val_loss: 0.8729
# Epoch 152/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 1.0403 - val_loss: 0.8715
# Epoch 153/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0385 - val_loss: 0.8702
# Epoch 154/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0366 - val_loss: 0.8688
# Epoch 155/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 1.0347 - val_loss: 0.8675
# Epoch 156/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0329 - val_loss: 0.8662
# Epoch 157/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0310 - val_loss: 0.8648
# Epoch 158/10000
# 1/1 [==============================] - 0s 170ms/step - loss: 1.0292 - val_loss: 0.8635
# Epoch 159/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0274 - val_loss: 0.8622
# Epoch 160/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0255 - val_loss: 0.8608
# Epoch 161/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0237 - val_loss: 0.8595
# Epoch 162/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0219 - val_loss: 0.8582
# Epoch 163/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0201 - val_loss: 0.8569
# Epoch 164/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0183 - val_loss: 0.8556
# Epoch 165/10000
# 1/1 [==============================] - 0s 163ms/step - loss: 1.0165 - val_loss: 0.8543
# Epoch 166/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 1.0147 - val_loss: 0.8530
# Epoch 167/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0129 - val_loss: 0.8517
# Epoch 168/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0111 - val_loss: 0.8504
# Epoch 169/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0093 - val_loss: 0.8491
# Epoch 170/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 1.0076 - val_loss: 0.8479
# Epoch 171/10000
# 1/1 [==============================] - 0s 167ms/step - loss: 1.0058 - val_loss: 0.8466
# Epoch 172/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0040 - val_loss: 0.8453
# Epoch 173/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0023 - val_loss: 0.8440
# Epoch 174/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0005 - val_loss: 0.8428
# Epoch 175/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.9988 - val_loss: 0.8415
# Epoch 176/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.9971 - val_loss: 0.8403
# Epoch 177/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.9953 - val_loss: 0.8390
# Epoch 178/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.9936 - val_loss: 0.8378
# Epoch 179/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.9919 - val_loss: 0.8365
# Epoch 180/10000
# 1/1 [==============================] - 0s 172ms/step - loss: 0.9902 - val_loss: 0.8353
# Epoch 181/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9885 - val_loss: 0.8340
# Epoch 182/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.9868 - val_loss: 0.8328
# Epoch 183/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.9851 - val_loss: 0.8316
# Epoch 184/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.9834 - val_loss: 0.8303
# Epoch 185/10000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.9817 - val_loss: 0.8291
# Epoch 186/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.9800 - val_loss: 0.8279
# Epoch 187/10000
# 1/1 [==============================] - 0s 160ms/step - loss: 0.9784 - val_loss: 0.8267
# Epoch 188/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.9767 - val_loss: 0.8255
# Epoch 189/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.9750 - val_loss: 0.8242
# Epoch 190/10000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.9734 - val_loss: 0.8230
# Epoch 191/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9717 - val_loss: 0.8218
# Epoch 192/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9701 - val_loss: 0.8206
# Epoch 193/10000
# 1/1 [==============================] - 0s 163ms/step - loss: 0.9684 - val_loss: 0.8194
# Epoch 194/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.9668 - val_loss: 0.8182
# Epoch 195/10000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.9652 - val_loss: 0.8170
# Epoch 196/10000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.9635 - val_loss: 0.8159
# Epoch 197/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9619 - val_loss: 0.8147
# Epoch 198/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9603 - val_loss: 0.8135
# Epoch 199/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.9587 - val_loss: 0.8123
# Epoch 200/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.9571 - val_loss: 0.8111
# Epoch 201/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.9555 - val_loss: 0.8100
# Epoch 202/10000
# 1/1 [==============================] - 0s 169ms/step - loss: 0.9539 - val_loss: 0.8088
# Epoch 203/10000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.9523 - val_loss: 0.8076
# Epoch 204/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.9507 - val_loss: 0.8065
# Epoch 205/10000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.9491 - val_loss: 0.8053
# Epoch 206/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9475 - val_loss: 0.8042
# Epoch 207/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.9460 - val_loss: 0.8030
# Epoch 208/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.9444 - val_loss: 0.8019
# Epoch 209/10000
# 1/1 [==============================] - 0s 171ms/step - loss: 0.9428 - val_loss: 0.8007
# Epoch 210/10000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.9413 - val_loss: 0.7996
# Epoch 211/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.9397 - val_loss: 0.7984
# Epoch 212/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.9382 - val_loss: 0.7973
# Epoch 213/10000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.9366 - val_loss: 0.7962
# Epoch 214/10000
# 1/1 [==============================] - 0s 81ms/step - loss: 0
#   (3,7)  20.0000 ~= 33.8476
#   (4,0)  16.0578 ~= 14.0091
# MatrixFactorization MSE: 86.4085, MAE: 4.5598

# %%
from fancyimpute import IterativeSVD

def test_iterative_svd_with_low_rank_random_matrix():
    solver = IterativeSVD(rank=2)
    aux_completed = solver.fit_transform(aux_incomplete)
    _, missing_mae = reconstruction_error(
        aux_arr,
        aux_completed,
        missing_mask,
        name="IterativeSVD")
    #assert missing_mae < 1.2, "Error too high!"
    return aux_completed


aux_completedSVD = test_iterative_svd_with_low_rank_random_matrix()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-ae7879f9f8ea> in <module>()
#      13
#      14
# ---> 15 aux_completedSVD = test_iterative_svd_with_low_rank_random_matrix()
#
# <ipython-input-21-ae7879f9f8ea> in test_iterative_svd_with_low_rank_random_matrix()
#       3 def test_iterative_svd_with_low_rank_random_matrix():
#       4     solver = IterativeSVD(rank=2)
# ----> 5     aux_completed = solver.fit_transform(aux_incomplete)
#       6     _, missing_mae = reconstruction_error(
#       7         aux_arr,
#
# /usr/local/lib/python3.6/dist-packages/fancyimpute/solver.py in fit_transform(self, X, y)
#     175         on new `X_test`.
#     176         """
# --> 177         X_original, missing_mask = self.prepare_input_data(X)
#     178         observed_mask = ~missing_mask
#     179         X = X_original.copy()
#
# /usr/local/lib/python3.6/dist-packages/fancyimpute/solver.py in prepare_input_data(self, X)
#     128         values are valid. Returns X and missing mask.
#     129         """
# --> 130         X = check_array(X, force_all_finite=False)
#     131         if X.dtype != "f" and X.dtype != "d":
#     132             X = X.astype(float)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '2019-08-28'

# %%
from fancyimpute import SoftImpute

def test_soft_impute_with_low_rank_random_matrix():
    solver = SoftImpute()
    aux_completed = solver.fit_transform(aux_incomplete)
    _, missing_mae = reconstruction_error(
        aux_arr,
        aux_completed,
        missing_mask,
        name="SoftImpute")
    #assert missing_mae < 0.1, "Error too high!"
    return aux_completed

aux_completed3= test_soft_impute_with_low_rank_random_matrix()
# Out:
# [SoftImpute] Max Singular Value of X_init = 2128.656606
# [SoftImpute] Iter 1: observed MAE=0.739584 rank=8
# [SoftImpute] Iter 2: observed MAE=0.753866 rank=8
# [SoftImpute] Iter 3: observed MAE=0.766748 rank=8
# [SoftImpute] Iter 4: observed MAE=0.776813 rank=8
# [SoftImpute] Iter 5: observed MAE=0.784489 rank=8
# [SoftImpute] Iter 6: observed MAE=0.790819 rank=8
# [SoftImpute] Iter 7: observed MAE=0.796280 rank=8
# [SoftImpute] Iter 8: observed MAE=0.801412 rank=8
# [SoftImpute] Iter 9: observed MAE=0.806207 rank=8
# [SoftImpute] Iter 10: observed MAE=0.810757 rank=8
# [SoftImpute] Iter 11: observed MAE=0.814875 rank=8
# [SoftImpute] Iter 12: observed MAE=0.818571 rank=8
# [SoftImpute] Iter 13: observed MAE=0.821941 rank=8
# [SoftImpute] Iter 14: observed MAE=0.824804 rank=8
# [SoftImpute] Iter 15: observed MAE=0.827093 rank=8
# [SoftImpute] Iter 16: observed MAE=0.828874 rank=8
# [SoftImpute] Iter 17: observed MAE=0.830117 rank=8
# [SoftImpute] Iter 18: observed MAE=0.830965 rank=8
# [SoftImpute] Iter 19: observed MAE=0.831556 rank=8
# [SoftImpute] Iter 20: observed MAE=0.831934 rank=8
# [SoftImpute] Iter 21: observed MAE=0.832150 rank=8
# [SoftImpute] Iter 22: observed MAE=0.832261 rank=8
# [SoftImpute] Iter 23: observed MAE=0.832295 rank=8
# [SoftImpute] Iter 24: observed MAE=0.832264 rank=8
# [SoftImpute] Iter 25: observed MAE=0.832213 rank=8
# [SoftImpute] Iter 26: observed MAE=0.832134 rank=8
# [SoftImpute] Iter 27: observed MAE=0.832033 rank=8
# [SoftImpute] Iter 28: observed MAE=0.831910 rank=8
# [SoftImpute] Iter 29: observed MAE=0.831782 rank=8
# [SoftImpute] Iter 30: observed MAE=0.831653 rank=8
# [SoftImpute] Iter 31: observed MAE=0.831513 rank=8
# [SoftImpute] Iter 32: observed MAE=0.831363 rank=8
# [SoftImpute] Iter 33: observed MAE=0.831202 rank=8
# [SoftImpute] Iter 34: observed MAE=0.831037 rank=8
# [SoftImpute] Iter 35: observed MAE=0.830867 rank=8
# [SoftImpute] Iter 36: observed MAE=0.830701 rank=8
# [SoftImpute] Iter 37: observed MAE=0.830540 rank=8
# [SoftImpute] Iter 38: observed MAE=0.830383 rank=8
# [SoftImpute] Iter 39: observed MAE=0.830230 rank=8
# [SoftImpute] Iter 40: observed MAE=0.830083 rank=8
# [SoftImpute] Iter 41: observed MAE=0.829942 rank=8
# [SoftImpute] Iter 42: observed MAE=0.829810 rank=8
# [SoftImpute] Iter 43: observed MAE=0.829685 rank=8
# [SoftImpute] Iter 44: observed MAE=0.829571 rank=8
# [SoftImpute] Iter 45: observed MAE=0.829460 rank=8
# [SoftImpute] Iter 46: observed MAE=0.829355 rank=8
# [SoftImpute] Iter 47: observed MAE=0.829262 rank=8
# [SoftImpute] Iter 48: observed MAE=0.829172 rank=8
# [SoftImpute] Iter 49: observed MAE=0.829084 rank=8
# [SoftImpute] Iter 50: observed MAE=0.829001 rank=8
# [SoftImpute] Iter 51: observed MAE=0.828922 rank=8
# [SoftImpute] Iter 52: observed MAE=0.828846 rank=8
# [SoftImpute] Iter 53: observed MAE=0.828772 rank=8
# [SoftImpute] Iter 54: observed MAE=0.828703 rank=8
# [SoftImpute] Iter 55: observed MAE=0.828638 rank=8
# [SoftImpute] Iter 56: observed MAE=0.828579 rank=8
# [SoftImpute] Iter 57: observed MAE=0.828525 rank=8
# [SoftImpute] Iter 58: observed MAE=0.828475 rank=8
# [SoftImpute] Iter 59: observed MAE=0.828428 rank=8
# [SoftImpute] Iter 60: observed MAE=0.828385 rank=8
# [SoftImpute] Iter 61: observed MAE=0.828344 rank=8
# [SoftImpute] Iter 62: observed MAE=0.828306 rank=8
# [SoftImpute] Iter 63: observed MAE=0.828270 rank=8
# [SoftImpute] Iter 64: observed MAE=0.828239 rank=8
# [SoftImpute] Iter 65: observed MAE=0.828211 rank=8
# [SoftImpute] Iter 66: observed MAE=0.828186 rank=8
# [SoftImpute] Iter 67: observed MAE=0.828162 rank=8
# [SoftImpute] Iter 68: observed MAE=0.828141 rank=8
# [SoftImpute] Iter 69: observed MAE=0.828120 rank=8
# [SoftImpute] Iter 70: observed MAE=0.828103 rank=8
# [SoftImpute] Iter 71: observed MAE=0.828086 rank=8
# [SoftImpute] Iter 72: observed MAE=0.828071 rank=8
# [SoftImpute] Iter 73: observed MAE=0.828057 rank=8
# [SoftImpute] Iter 74: observed MAE=0.828044 rank=8
# [SoftImpute] Iter 75: observed MAE=0.828032 rank=8
# [SoftImpute] Iter 76: observed MAE=0.828020 rank=8
# [SoftImpute] Iter 77: observed MAE=0.828010 rank=8
# [SoftImpute] Iter 78: observed MAE=0.828001 rank=8
# [SoftImpute] Iter 79: observed MAE=0.827992 rank=8
# [SoftImpute] Iter 80: observed MAE=0.827984 rank=8
# [SoftImpute] Iter 81: observed MAE=0.827978 rank=8
# [SoftImpute] Stopped after iteration 81 for lambda=42.573132
# First 10 reconstructed values:
#   (0,4)  11.0000 ~= 12.3314
#   (1,6)  5.0000 ~= 7.3659
#   (1,7)  20.0000 ~= 19.0024
#   (2,0)  16.0578 ~= 10.7129
#   (3,1)  6.0000 ~= 4.0768
#   (3,4)  11.0000 ~= 12.1843
#   (4,1)  6.0000 ~= 3.9286
#   (4,3)  5.0000 ~= 2.5448
#   (4,4)  11.0000 ~= 12.1702
#   (5,0)  12.0000 ~= 8.7099
# SoftImpute MSE: 123.1480, MAE: 4.2178

# %%
aux_completedSI= pd.DataFrame(aux_completed3, columns = columnsp, index= indixp)
aux_completedSI =aux_completed33.reset_index()
aux_completedSI['sensor10v2.csv'].plot()

# %%
aux_completed= pd.DataFrame(aux_completed, columns = columnst, index= indext)
aux_completed =aux_completed.reset_index()

# %%
plt.figure(figsize=(20,5))
plt.axis([0,1500, 0, 70])
plt.plot(aux_completed['sensor10v2.csv'],'b')
plt.title('Average PM2 filled by Matrix Completion', size=15)
plt.xlabel('time',size=15)
plt.ylabel('PM2 Moyenne',size=15)
# Out:
# Text(0, 0.5, 'PM2 Moyenne')

# %%
aux = aux.reset_index()

# %%
plt.figure(figsize=(20,5))
plt.axis([0,1500, 0, 70])
plt.plot(aux['sensor10v2.csv'],'r')
plt.title('Average PM2 filled by Matrix Completion', size=15)
plt.xlabel('time',size=15)
plt.ylabel('PM2 Moyenne',size=15)
# Out:
# Text(0, 0.5, 'PM2 Moyenne')

# %%
aux_completed2 = pd.DataFrame(aux_completed2, columns = ['PM2_MAX','PM2_MOY'])
aux_completed2[['Sensor', 'Date', 'Hour', 'PM2_MIN']] = aux[['Sensor', 'Date', 'Hour', 'PM2_MIN']]
aux_completed2 = aux_completed2[['Sensor', 'Date', 'Hour', 'PM2_MIN', 'PM2_MAX', 'PM2_MOY']]
aux_completed2['Date'] = pd.to_datetime(aux_completed2['Date'])
aux['Date'] = pd.to_datetime(aux['Date'])
aux_completed2 = aux_completed2.sort_values(by='Date')
aux = aux.sort_values(by='Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1670                 blocks = [
# -> 1671                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1672                 ]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2743
# -> 2744     return klass(values, ndim=ndim, placement=placement)
#    2745
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     130             raise ValueError(
# --> 131                 f"Wrong number of items passed {len(self.values)}, "
#     132                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 1362, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-238-130828436150> in <module>()
# ----> 1 aux_completed2 = pd.DataFrame(aux_completed2, columns = ['PM2_MAX','PM2_MOY'])
#       2 aux_completed2[['Sensor', 'Date', 'Hour', 'PM2_MIN']] = aux[['Sensor', 'Date', 'Hour', 'PM2_MIN']]
#       3 aux_completed2 = aux_completed2[['Sensor', 'Date', 'Hour', 'PM2_MIN', 'PM2_MAX', 'PM2_MOY']]
#       4 aux_completed2['Date'] = pd.to_datetime(aux_completed2['Date'])
#       5 aux['Date'] = pd.to_datetime(aux['Date'])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1679         blocks = [getattr(b, "values", b) for b in blocks]
#    1680         tot_items = sum(b.shape[0] for b in blocks)
# -> 1681         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1682
#    1683
#
# ValueError: Shape of passed values is (8, 1362), indices imply (8, 2)

# %%
aux_completed3 = pd.DataFrame(aux_completed3, columns = ['PM2_MAX','PM2_MOY'])
aux_completed3[['Sensor', 'Date', 'Hour', 'PM2_MIN']] = aux[['Sensor', 'Date', 'Hour', 'PM2_MIN']]
aux_completed3 = aux_completed3[['Sensor', 'Date', 'Hour', 'PM2_MIN', 'PM2_MAX', 'PM2_MOY']]
aux_completed3['Date'] = pd.to_datetime(aux_completed3['Date'])
aux['Date'] = pd.to_datetime(aux['Date'])
aux_completed3 = aux_completed3.sort_values(by='Date')
aux = aux.sort_values(by='Date')

# %%
d =pd.DataFrame(aux_incomplete, columns=['PM2_Max', 'PM2_MOY'])
d['PM2_MOY'].isnull().sum().sum()
# Out:
# 1519

# %%
aux['PM2_MOY'].shape
# Out:
# (5088,)

# %%
print(aux_completed2.describe())
np.isnan(aux_incomplete).sum()
# Out:
#               Hour      PM2_MIN      PM2_MAX      PM2_MOY
# count  5088.000000  5088.000000  5088.000000  5088.000000
# mean     11.454009     6.313679     8.807687     7.179792
# std       6.938059     8.840586    11.766527     9.973181
# min       0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     2.000000     3.000000     2.000000
# 50%      11.000000     4.000000     6.000000     5.000000
# 75%      17.000000     7.000000    10.000000     8.000000
# max      23.000000   203.000000   207.000000   201.000000
# 2983

# %%
plt.figure(figsize=(20,5))
plt.axis([0,5200, 0, 70])
plt.plot(arrcompletedknn['PM2_MOY'],'bo')
plt.title('Average PM2 filled by Matrix Completion', size=15)
plt.xlabel('time',size=15)
plt.ylabel('PM2 Moyenne',size=15)
# Out:
# Text(0, 0.5, 'PM2 Moyenne')

# %%
plt.figure(figsize=(20,5))
plt.axis([0,5200, 0, 70])
plt.plot(aux['PM2_MOY'], 'ro')
plt.title('Average PM2 Original', size=15)
plt.xlabel('time', size=15)
plt.ylabel('PM2 Moyenne', size=15)
# Out:
# Text(0, 0.5, 'PM2 Moyenne')

# %%
aux['PM2_MOY'].max()
# Out:
# 136.0

# %%
aux_completed33['Date'] = pd.to_datetime(aux_completed33['Date'])
aux['Date'] = pd.to_datetime(aux['Date'])
aux_completed33 = aux_completed33.sort_values(by='Date')
aux = aux.sort_values(by='Date')

# %%
# Affichage
def plot_df(df, x, y, title="qu'est-ce ?", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
plot_df(aux_completed33, x=aux_completed33['Date'], y=aux_completed33['sensor10v2.csv'],title='PM2MAX par heure  - RTE 01/11/2018 - 28/10/2019')

# %%
plot_df(aux, x=aux['Date'], y=aux['PM2_MOY'],title='PM2MAX par heure  - RTE 01/11/2018 - 28/10/2019')

# %%
from fancyimpute import (NuclearNormMinimization)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
def test_nuclear_norm_minimization_with_low_rank_random_matrix():
    solver = NuclearNormMinimization(max_iters=2000)
    XY_completed = solver.fit_transform(aux_incomplete[0:4000])
    _, missing_mae = reconstruction_error(
        aux_arr[0:4000], XY_completed, missing_mask[0:4000], name="NuclearNorm")
    #assert missing_mae < 0.1, "Error too high!"
    return XY_completed

# %%
 aux_completed = test_nuclear_norm_minimization_with_low_rank_random_matrix()
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 7376191
# eps = 1.00e-04, alpha = 1.50, max_iters = 2000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7324839, constraints m = 7347747
# Cones:	primal zero / dual free vars: 11454
# 	linear vars: 34362
# 	sd vars: 7301931, sd blks: 1
# Setup time: 9.10e+00s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------

# %%
aux_completed = pd.DataFrame(aux_completed, columns = ['PM2_MIN','PM2_MAX','PM2_MOY'])
aux_completed[['Sensor', 'Date', 'Hour']] = aux[['Sensor', 'Date', 'Hour']]
aux_completed = aux_completed[['Sensor', 'Date', 'Hour', 'PM2_MIN', 'PM2_MAX', 'PM2_MOY']]
aux_completed['Date'] = pd.to_datetime(aux_completed['Date'])
aux['Date'] = pd.to_datetime(aux['Date'])

# %%
super_df['PM2_MOY'].describe()
# Out:
# count    55474.000000
# mean        14.333201
# std         23.093834
# min          0.000000
# 25%          3.000000
# 50%          7.000000
# 75%         15.000000
# max        315.000000
# Name: PM2_MOY, dtype: float64

# %%
super_df['PM2_MOY'].isnull().sum().sum()
# Out:
# 8510

# %%
(8510 * 100 ) / 55474
# Out:
# 15.34051988318852

# %% [markdown]
# # Nuevo codigo MF

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.interpolate import Rbf, InterpolatedUnivariateSpline

# %%
def reconstruction_error(XY, XY_completed, missing_mask, name=None):
    """
    Returns mean squared error and mean absolute error for
    completed matrices.
    """
    value_pairs = [
        (i, j, XY[i, j], XY_completed[i, j])
        for i in range(XY.shape[0])
        for j in range(XY.shape[1])
        if missing_mask[i, j]
    ]
    print("First 10 reconstructed values:")
    for (i, j, x, xr) in value_pairs[:10]:
        print("  (%d,%d)  %0.4f ~= %0.4f" % (i, j, x, xr))
    diffs = [actual - predicted for (_, _, actual, predicted) in value_pairs]
    missing_mse = np.sqrt(np.mean([diff ** 2 for diff in diffs]))
    missing_mae = np.mean([np.abs(diff) for diff in diffs])
    print("%s RMSE: %0.4f, MAE: %0.4f" % (
        "" if not name else name + " ",
        missing_mse,
        missing_mae))
    return missing_mse, missing_mae

# %%
super_df = pd.read_csv('/content/drive/MyDrive/IMT Atlantique/Project_S5_Air/air-polution-sensor/data/superdfi.csv', header=0, index_col=0)
aux = super_df[(super_df['Sensor'] == 'sensor14v2.csv') | (super_df['Sensor'] == 'sensor13v2.csv') | (super_df['Sensor'] == 'sensor12v2.csv') | (super_df['Sensor'] == 'sensor11v2.csv') | (super_df['Sensor'] == 'sensor10v2.csv') | (super_df['Sensor'] == 'sensor9v2.csv') | (super_df['Sensor'] == 'sensor8v2.csv') | (super_df['Sensor'] == 'sensor7v2.csv') ]

# %%
aux = pd.pivot_table(data=aux,values='PM2_MOY',index=['Date', 'Hour'],columns='Sensor' )
aux = aux.fillna(aux.mean())
columnst = aux.columns
indext = aux.index

# %%
aux_arr = aux.to_numpy()
aux_incomplete =  np.copy(aux_arr)
missing_raw_values = np.random.uniform(0, 1, aux_arr.shape)
missing_mask = missing_raw_values < 0.2
aux_incomplete[missing_mask] = np.nan

# %%
aux_incomplete = pd.DataFrame(aux_incomplete, columns = columnst, index= indext).reset_index()

# %%
aux_incomplete.iloc[:, 2:10] = aux_incomplete.iloc[:, 2:10].interpolate(method='polynomial', order=5)
arr_completed = aux_incomplete.iloc[:, 2:10].to_numpy()

# %%
rmse, missing_mae = reconstruction_error(
        aux.to_numpy(),
        arr_completed,
        missing_mask,
        name="SoftImpute")
# Out:
# First 10 reconstructed values:
#   (0,0)  16.0578 ~= nan
#   (0,3)  5.0000 ~= nan
#   (0,6)  5.0000 ~= nan
#   (1,1)  6.0000 ~= 5.6020
#   (1,7)  20.0000 ~= 20.0000
#   (2,0)  16.0578 ~= 18.5422
#   (2,3)  5.0000 ~= 5.0000
#   (2,6)  4.0000 ~= 4.1545
#   (3,3)  5.0000 ~= 5.0000
#   (3,4)  11.0000 ~= 11.0000
# SoftImpute RMSE: nan, MAE: nan

# %%
a = aux['sensor8v2.csv']

# %%
plt.figure(figsize=(20,5))
plt.axis([0,1500, 0, 110])
plt.plot(a['sensor8v2.csv'].reset_index(),'b')
plt.title('Average PM2 filled by Matrix Completion', size=15)
plt.xlabel('time',size=15)
plt.ylabel('PM2 Moyenne',size=15)
# Out:
# Text(0, 0.5, 'PM2 Moyenne')

# %%
b = aux_incomplete['sensor8v2.csv'].reset_index()

# %%
plt.figure(figsize=(20,5))
plt.axis([0,1500, 0, 110])
plt.plot(b['sensor8v2.csv'],'b')
plt.title('Average PM2 filled by Matrix Completion', size=15)
plt.xlabel('time',size=15)
plt.ylabel('PM2 Moyenne',size=15)
# Out:
# Text(0, 0.5, 'PM2 Moyenne')
